# %% [markdown]
# # **INFO5731 In-class Exercise 4**
#
# **This exercise will provide a valuable learning experience in working with text data and extracting features using various topic modeling algorithms. Key concepts such as Latent Dirichlet Allocation (LDA), Latent Semantic Analysis (LSA), lda2vec, and BERTopic.**

# %% [markdown]
# ***Please use the text corpus you collected in your last in-class-exercise for this exercise. Perform the following tasks***.
#
# **Expectations**:
# *   Students are expected to complete the exercise during lecture period to meet the active participation criteria of the course.
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# **Total points**: 40
#
# **Deadline**: This in-class exercise is due at the end of the day tomorrow, at 11:59 PM.
#
# **Late submissions will have a penalty of 10% of the marks for each day of late submission, and no requests will be answered. Manage your time accordingly.**

# %%
#sample corpus from the previous exercise
review_1 = """I recently purchased the Smart Home Security System, and I must say, it has exceeded all my expectations! This product has completely transformed the way I approach home security, providing peace of mind like never before.
Let's start with the installation process. I was initially concerned about the complexity of setting up a smart security system, but to my surprise, the whole process was incredibly user-friendly. The step-by-step instructions and intuitive interface made it a breeze to get everything up and running. In no time, I had cameras strategically placed around my home and sensors seamlessly integrated into key areas.
The video quality of the cameras is outstanding. The high-definition resolution captures every detail, ensuring crystal-clear footage day and night. The wide-angle lenses provide comprehensive coverage, allowing me to monitor my entire property with ease. Plus, the infrared night vision is impressive, maintaining clarity even in low-light conditions.
One of the standout features for me is the real-time mobile alerts. The system sends instant notifications to my smartphone whenever motion is detected or a sensor is triggered. This level of responsiveness gives me a sense of control and awareness, whether I'm at home or away. It's incredibly reassuring to know that I'll be alerted immediately if anything out of the ordinary occurs.
The integration with smart home platforms is seamless. I can easily control and monitor the security system using voice commands through my smart assistant. This level of convenience adds an extra layer of sophistication to the overall experience.
What sets this Smart Home Security System apart is its robust and customizable features. I can create specific zones for monitoring, adjust sensitivity levels, and even set up custom schedules. The flexibility to tailor the system to my preferences makes it a truly personalized security solution.
The two-way audio communication feature is another game-changer. Whether it's communicating with delivery personnel, checking in on family members, or deterring potential intruders, the ability to speak through the cameras adds an interactive element that goes beyond traditional security systems.
Moreover, the product's compatibility with cloud storage ensures that I can access recorded footage at any time. The peace of mind that comes from knowing my video history is securely stored is invaluable.
In conclusion, the Smart Home Security System has proven to be a wise investment for my family and me. Its user-friendly setup, top-notch features, and seamless integration into our daily lives have made it an essential component of our home. I wholeheartedly recommend this product to anyone looking to elevate their home security to a smarter and more efficient level."
"""

review_2 = """I recently purchased the XYZ Smartwatch, and to be honest, it has been nothing short of a disappointment. I had high hopes for this product, given the promising features listed on the website, but the reality falls far short of expectations.
Let's start with the build quality. The XYZ Smartwatch feels incredibly cheap and flimsy. The plastic casing gives it a tacky appearance, and I can't help but question the durability of this device. It doesn't exude the premium feel that one would expect, especially considering the price point.
The advertised battery life is laughable. Despite the manufacturer's claims, the battery barely lasts through a single day of regular use. Charging this smartwatch has become an annoying daily ritual, and the charging time is far from convenient. The battery indicator is unreliable, often showing false levels that leave me stranded with a dead device.
The touch screen is another major letdown. It lacks responsiveness, and navigating through menus feels clunky and unresponsive. Swiping gestures are often misinterpreted, leading to frustration rather than convenience. The user interface is poorly designed, making it cumbersome to access essential functions quickly.
The health tracking features, touted as a highlight of the XYZ Smartwatch, are unreliable at best. The heart rate monitor provides erratic readings, and the sleep tracking feature seems to confuse periods of restlessness with actual sleep. I can't trust the data it provides, rendering these features practically useless.
Syncing the smartwatch with my phone has become a constant struggle. The companion app is glitchy and prone to crashes, making the overall user experience a nightmare. Notifications are delayed, and sometimes they don't even come through. What's the point of a smartwatch if it fails to deliver timely alerts?
The XYZ Smartwatch lacks essential features that have become standard in other devices within its price range. The absence of GPS functionality, limited app compatibility, and the inability to respond to messages directly from the watch are glaring drawbacks. It feels like a product stuck in the past rather than one designed for the future.
In conclusion, the XYZ Smartwatch is a regrettable purchase. Its subpar build quality, disappointing battery life, unreliable health tracking, and frustrating user experience make it a product I cannot recommend. Save your money and explore more reputable options in the smartwatch market. This device fails to deliver on its promises, leaving users with a sense of frustration and buyer's remorse.
"""

review_3 = """I recently acquired the XYZ Smartwatch, and I must say, it has completely exceeded my expectations. This smartwatch has become an indispensable part of my daily life, seamlessly blending style and functionality.
To begin with, the build quality is outstanding. The sleek and modern design not only looks great on my wrist but also feels durable and well-crafted. The attention to detail in the construction gives it a premium feel that sets it apart from other smartwatches in the market.
The XYZ Smartwatch boasts an impressive battery life that genuinely delivers on its promises. I can go for days without worrying about charging, making it a reliable companion for both short and extended adventures. The quick-charging feature is an added bonus, ensuring that I'm never without my favorite wearable for too long.
Navigating through the smartwatch's interface is a delight. The responsive touch screen and intuitive user interface make accessing features and apps a breeze. Swiping through notifications, checking health stats, and customizing watch faces are seamless experiences that add to the overall satisfaction of using this device.
Health and fitness tracking are where the XYZ Smartwatch truly shines. The accuracy of the heart rate monitor and the insightful sleep tracking feature have provided valuable insights into my well-being. The integration with fitness apps enhances my workout routines, and the real-time tracking motivates me to stay active throughout the day.
Syncing the smartwatch with my smartphone is hassle-free. The companion app is well-designed, providing a comprehensive overview of my health data and allowing for easy customization of settings. Notifications are delivered promptly, and the ability to respond to messages directly from my wrist adds a level of convenience that I now find indispensable.
The XYZ Smartwatch comes equipped with essential features that elevate its functionality. The inclusion of GPS enhances outdoor activities, and the water-resistant design ensures I can wear it in various environments without worry. The abundance of available apps and watch faces allows for a personalized experience that suits my unique preferences.
In conclusion, the XYZ Smartwatch has proven to be an exceptional investment. Its stylish design, reliable battery life, intuitive interface, and robust health tracking features make it a standout in the smartwatch market. I wholeheartedly recommend it to anyone in search of a versatile and reliable wearable that seamlessly integrates into their daily routine.
"""

reviews = review_1 + review_2 + review_3
reviews = reviews.lower()

# %% [markdown]
# ## Question 1 (10 Points)
#
# **Generate K topics by using LDA, the number of topics K should be decided by the coherence score, then summarize what are the topics.**
#
# You may refer the code here: https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/

# %%
# Write your code here
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

import re
import numpy as np
import pandas as pd
import string
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy
nlp = spacy.load('en_core_web_sm')

# Plotting tools
# !pip install pyldavis
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
#import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)

#remove newline
reviews_lda = re.sub('\s+', ' ', reviews)

#remove single quote
reviews_lda = re.sub("\'", "", reviews_lda)

#remove punctiation and tokenize
tokenizer = RegexpTokenizer(r'\w+')
reviews_lda = tokenizer.tokenize(reviews_lda)

#remove stopwords
stop_words = set(stopwords.words('english'))
reviews_lda = [w for w in reviews_lda if not w.lower() in stop_words]

#make bigram/trigram
reviews_lda_bigram = list(nltk.bigrams(reviews_lda))
reviews_lda_trigram = list(nltk.ngrams(reviews_lda,3))

#print(reviews_lda_bigram)
#print(reviews_lda_trigram)

#lemmatization
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

reviews_lda_lemmatized = lemmatization(reviews_lda_bigram, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])
#pprint(reviews_lda_lemmatized)

#Create Dictionary
id2word = corpora.Dictionary(reviews_lda_lemmatized)

# Create Corpus
texts = reviews_lda_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

'''
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=15, #initial number before finding the optimum coherence
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

pprint(lda_model.print_topics())
#doc_lda = lda_model[corpus]

# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
'''

#optimal number of K topics
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
  """
  Compute c_v coherence for various number of topics
  Parameters:
  ----------
  dictionary : corpora.Dictionary
  corpus : id2word.doc2bow
  texts : List of input texts
  limit : Max num of topics

  Returns:
  -------
  model_list : List of LDA topic models
  coherence_values : Coherence values corresponding to the LDA model with respective number of topics
  """
  coherence_values = []
  model_list = []
  for num_topics in range(start, limit, step):
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=num_topics,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

    model_list.append(lda_model)
    coherencemodel = CoherenceModel(model=lda_model, texts=texts, dictionary=dictionary, coherence='c_v')
    coherence_values.append(coherencemodel.get_coherence())

  return model_list, coherence_values

model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts, start=2, limit=40, step=6)

# Show graph
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

#rerun the model with k=2

print("\nBuild LDA Model\n")

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=2, #the most optimum coherence value
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

pprint(lda_model.print_topics())

# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 32.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# ...

# %% [markdown]
# ## Question 2 (10 Points)
#
# **Generate K topics by using LSA, the number of topics K should be decided by the coherence score, then summarize what are the topics.**
#
# You may refer the code here: https://www.datacamp.com/community/tutorials/discovering-hidden-topics-python

# %%
# Write your code here
#import modules
import os.path
from gensim import corpora
from gensim.models import LsiModel
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

def preprocess_data(doc_set):
    """
    Input  : document list
    Purpose: preprocess text (tokenize, removing stopwords, and stemming)
    Output : preprocessed text
    """
    # initialize regex tokenizer
    tokenizer = RegexpTokenizer(r'\w+')
    # create English stop words list
    en_stop = set(stopwords.words('english'))
    # Create p_stemmer of class PorterStemmer
    p_stemmer = PorterStemmer()
    # list for tokenized documents in loop
    texts = []
    # loop through document list
    #for i in doc_set:
    # clean and tokenize document string
    raw = doc_set.lower()
    tokens = tokenizer.tokenize(raw)
    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    # stem tokens
    stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
    # add tokens to list
    texts.append(stemmed_tokens)
    return texts

def prepare_corpus(doc_clean):
    """
    Input  : clean document
    Purpose: create term dictionary of our courpus and Converting list of documents (corpus) into Document Term Matrix
    Output : term dictionary and Document Term Matrix
    """
    # Creating the term dictionary of our corpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
    dictionary = corpora.Dictionary(doc_clean)
    # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
    # generate LDA model
    return dictionary,doc_term_matrix

def create_gensim_lsa_model(doc_clean,number_of_topics,words):
    """
    Input  : clean document, number of topics and number of words associated with each topic
    Purpose: create LSA model using gensim
    Output : return LSA model
    """
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    # generate LSA model
    lsamodel = LsiModel(doc_term_matrix, num_topics=number_of_topics, id2word = dictionary)  # train model
    print(lsamodel.print_topics(num_topics=number_of_topics, num_words=words))
    return lsamodel

def compute_coherence_values(dictionary, doc_term_matrix, doc_clean, stop, start=2, step=3):
    """
    Input   : dictionary : Gensim dictionary
              corpus : Gensim corpus
              texts : List of input texts
              stop : Max num of topics
    purpose : Compute c_v coherence for various number of topics
    Output  : model_list : List of LSA topic models
              coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []

    for num_topics in range(start, stop, step):
        # generate LSA model
        model = LsiModel(doc_term_matrix, num_topics=num_topics, id2word = dictionary)  # train model
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=doc_clean, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
    return model_list, coherence_values

def plot_graph(doc_clean,start, stop, step):
    dictionary,doc_term_matrix=prepare_corpus(doc_clean)
    model_list, coherence_values = compute_coherence_values(dictionary, doc_term_matrix,doc_clean,
                                                            stop, start, step)

    # Show graph
    x = range(start, stop, step)
    plt.plot(x, coherence_values)
    plt.xlabel("Number of Topics")
    plt.ylabel("Coherence score")
    plt.legend(("coherence_values"), loc='best')
    plt.show()

reviews_lsa = reviews
clean_text=preprocess_data(reviews_lsa)

start,stop,step=2,15,1

plot_graph(clean_text,start,stop,step)

# LSA Model
number_of_topics = 4
words=5
model=create_gensim_lsa_model(clean_text,number_of_topics,words)
# Out:
# [(0, '0.369*"smartwatch" + 0.272*"featur" + 0.194*"secur" + 0.194*"xyz" + 0.175*"home"')]

# %% [markdown]
# ## Question 3 (10 points):
# **Generate K topics by using lda2vec, the number of topics K should be decided by the coherence score, then summarize what are the topics.**
#
# You may refer the code here: https://nbviewer.org/github/cemoody/lda2vec/blob/master/examples/twenty_newsgroups/lda2vec/lda2vec.ipynb

# %%
# Write your code here
# can't replicate the code
# however since lda2vec is a combination of LDA and word2vec, below is the word2vec that process LDA terms from the same corpus.

# importing all necessary modules
import nltk
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

import gensim
from gensim.models import Word2Vec
import warnings
import re

from sklearn.decomposition import PCA
from matplotlib import pyplot

warnings.filterwarnings(action='ignore')

#remove newline
reviews_word2vec = re.sub('\s+', ' ', reviews)

#remove single quote
reviews_word2vec = re.sub("\'", "", reviews_word2vec)

#remove punctuation and tokenize
tokenizer = RegexpTokenizer(r'\w+')
reviews_word2vec = tokenizer.tokenize(reviews_word2vec)

#remove stopwords
stop_words = set(stopwords.words('english'))
reviews_word2vec = [w for w in reviews_word2vec if not w.lower() in stop_words]

# Create CBOW model
model = gensim.models.Word2Vec(window=5, min_count=2, workers=4)
model.build_vocab([s.encode('utf-8').split( ) for s in reviews_word2vec])

print(model.wv.key_to_index)

#get topics from the LDA, visualize the words using the word2vec model
print("\n"+lda_model.print_topics()[0][1]+"\n")

#extract the LDA terms
terms = re.findall(r'"(.+?)"', lda_model.print_topics()[0][1])
terms_byte = []
for t in terms:
  terms_byte.append(bytes(t, 'utf-8'))

#feed the LDA terms into the word2vec model and visualize
x = model.wv[terms_byte[:8]]
pca = PCA(n_components=2)
result = pca.fit_transform(x)

pyplot.scatter(result[:, 0], result[:, 1])
for i, word in enumerate(terms_byte[:8]):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

#i dont know what i am doing!
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %% [markdown]
# ## Question 4 (10 points):
# **Generate K topics by using BERTopic, the number of topics K should be decided by the coherence score, then summarize what are the topics.**
#
# You may refer the code here: https://colab.research.google.com/drive/1FieRA9fLdkQEGDIMYl0I3MCjSUKVF8C-?usp=sharing

# %%
# Write your code here
# !pip install bertopic
# !pip install bertviz

from bertopic import BERTopic

import nltk
from nltk.tokenize import RegexpTokenizer
nltk.download('stopwords')
from nltk.corpus import stopwords


topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)

#tokenize
tokenizer = RegexpTokenizer(r'\w+')
reviews_bert = tokenizer.tokenize(reviews)

#remove stopwords
stop_words = set(stopwords.words('english'))
reviews_bert = [w for w in reviews_bert if not w.lower() in stop_words]

topics, probs = topic_model.fit_transform(reviews_bert)

freq = topic_model.get_topic_info();
freq.head(5)

topic_model.get_topic(0)

#topic_model.topics_[:10]
#topic_model.visualize_topics()
#topic_model.visualize_distribution(probs[200], min_probability=0.015)
#topic_model.visualize_hierarchy(top_n_topics=50)
#topic_model.visualize_barchart(top_n_topics=5)
#topic_model.visualize_heatmap(n_clusters=20, width=1000, height=1000)
#topic_model.visualize_term_rank()
#topic_model.update_topics(reviews_bert, n_gram_range=(1, 2))
#topic_model.get_topic(0)   # We select topic that we viewed before
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-02 03:29:21,912 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/24 [00:00<?, ?it/s]
# 2024-04-02 03:29:24,827 - BERTopic - Embedding - Completed ✓
# 2024-04-02 03:29:24,830 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-04-02 03:29:30,115 - BERTopic - Dimensionality - Completed ✓
# 2024-04-02 03:29:30,117 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-04-02 03:29:30,209 - BERTopic - Cluster - Completed ✓
# 2024-04-02 03:29:30,219 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-04-02 03:29:30,275 - BERTopic - Representation - Completed ✓
# [('product', 0.19707403009397145),
#  ('conclusion', 0.1345239537144624),
#  ('market', 0.1345239537144624),
#  ('checking', 0.10469181050863414),
# ...

# %% [markdown]
# ## Extra Question (5 Points)
#
# **Compare the results generated by the four topic modeling algorithms, which one is better? You should explain the reasons in details.**
#
# **This question will compensate for any points deducted in this exercise. Maximum marks for the exercise is 40 points.**

# %%
# Write your code here
'''
I think the LDA implementation works the best. The coherence scores were constant, so it was easy to determine the ideal K value. I didn't know why, but the coherence scores in the sample code for LSA kept changing. It was hard to determine the optimum K value.

Meanwhile, in the BERTopic, the code was simpler, and the class loaded with features, but I felt the process was slow compared to LDA or LSA.



However, the captured topics are different for each model.
The LDA captures:

  '0.034*"smartwatch" + 0.025*"design" + 0.022*"make" + 0.018*"reliable" + '
  '0.018*"life" + 0.016*"battery" + 0.014*"interface" + 0.012*"user" + '
  '0.011*"provide" + 0.011*"recommend"'

The LSA:
(0, '0.369*"smartwatch" + 0.272*"featur" + 0.194*"secur" + 0.194*"xyz" + 0.175*"home"')

The lda2vec:
Can't make it work

BERTopic:
[('product', 0.19707403009397145),
 ('conclusion', 0.1345239537144624),
 ('market', 0.1345239537144624),
 ('checking', 0.10469181050863414),
 ('step', 0.10469181050863414),
 ('price', 0.10469181050863414),
 ('investment', 0.10469181050863414),
 ('proven', 0.10469181050863414),
 ('purchased', 0.10469181050863414),
 ('rate', 0.10469181050863414)]

The topics captured by the LDA and the LSA are relatively similar. However, the frequent topics on BERTopic are different.
'''

# %% [markdown]
# # Mandatory Question

# %% [markdown]
# **Important: Reflective Feedback on this exercise**
#
# Please provide your thoughts and feedback on the exercises you completed in this assignment.
#
# Consider the following points in your response:
#
# **Learning Experience:** Describe your overall learning experience in working with text data and extracting features using various topic modeling algorithms. Did you understand these algorithms and did the implementations helped in grasping the nuances of feature extraction from text data.
#
# **Challenges Encountered:** Were there specific difficulties in completing this exercise?
#
# Relevance to Your Field of Study: How does this exercise relate to the field of NLP?
#
# **(Your submission will not be graded if this question is left unanswered)**

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

The samples could not be run directly. Some tweaks were needed to make the code work.
For me, my time was mainly used to work on the tweaks rather than to understand the flow of the code.

Some topic modeling approaches, such as LDA, have code samples all over the internet due to their popularity.
But, I struggled to find a working sample for the lda2vec model. In the end, all models are like black boxes for me.
I know they are working, but I need help explaining the bolts and nuts.

However, I got the nuance of how this subtopic of NLP can be implemented. I have a perfect case in mind.
I will use these approaches to analyze scholarly papers hosted in the repository to get a bigger picture of the research direction of the institution.

'''
