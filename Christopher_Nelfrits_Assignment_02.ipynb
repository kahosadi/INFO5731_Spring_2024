# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# Your code here
#Densho Digital Repository

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
from urllib.error import HTTPError
import pandas as pd
import time
from google.colab import drive

start_time = time.time()

target_url = "https://ddr.densho.org/narrators/?page={}"
num_page = 40
narrator = ""

narrator_name = []
narrator_desc = []

for i in range(1, num_page):
  #open URL
  try:
    link = Request(target_url.format(i), headers={'User-Agent': 'Mozilla/5.0'})
    url = urlopen(link)

    data = url.read()
    retrieved_data = BeautifulSoup(data)

    #get narrator details
    narrator = retrieved_data.find_all("a", attrs={'class':'item-hover'})
  except ConnectionError as e:
    print(e)
  except Exception as e:
    print(e)

  for j in narrator:
    #open another request to get the narrators details
    try:
      profile_url = Request(j['href'], headers={'User-Agent': 'Mozilla/5.0'})
      profile_data = BeautifulSoup(urlopen(profile_url).read())

      narrator_detail = profile_data.find_all("div", attrs={'class':'col-sm-8 col-md-8'})

      for k in narrator_detail:
        print(k.h1.text)
        narrator_name.append(k.h1.text)
        narrator_desc.append(k.p.text)

        time.sleep(0.5)

    except ConnectionError as e:
      print(e)
    except Exception as e:
      print(e)

  dataframe = pd.DataFrame({"name": narrator_name, "desc": narrator_desc})

drive.mount('drive', force_remount=True)
dataframe.to_csv('/content/drive/My Drive/densho_11700380.csv', encoding='utf-8')

print("Completed in --- %s seconds ---" % (time.time() - start_time))
# Out:
#   Kay Aiko Abe
#
#
#   Art Abe
#
#
#   Sharon Tanagi Aburano
#
#
#   Toshiko Aiboshi
#
#
#   Douglas L. Aihara
#
#
#   Yae Aihara
#
#
#   Elaine Akagi
#
#
#   Nelson Takeo Akagi
#
#
#   Tom Akashi
#
#
#   Mas Akiyama
#
#
#   Sab Akiyama
#
#
#   Sumie Suguro Akizuki
#
#
#   Harry Akune
#
#
#   Kenjiro Akune
#
#
#   Gene Akutsu
#
#
#   Jim Akutsu
#
#
#   Dorothy Almojuela
#
#
#   Alice Matsumoto Ando
#
#
#   Emery Brooks Andrews
#
#
#   Margie Nahmias Angel
#
#
#   Dan Aoki
#
#
#   Nancy K. Araki
#
#
#   Sam Araki
#
#
#   Sakaye Aratani
#
#
#   Terry Aratani
#
#
#   Yoshiko Asakura
#
#
#   Setsuko Izumi Asano
#
#
#   George Azumano
#
#
#   Peggie Nishimura Bain
#
#
#   Sarah Baker
#
#
#   Dennis Bambauer
#
#
#   Kathryn Bannai
#
#
#   Lorraine Bannai
#
#
#   Paul Bannai
#
#
#   Yone Bartholomew
#
#
#   Gerald L. Beppu
#
#
#   June Yasuno Aochi (Yamashiro) Berk
#
#
#   Marion Michiko Bernardo
#
#
#   Angela Berry
#
#
#   Bob Berry
#
#
#   Ernest Besig
#
#
#   Theo Bickel
#
#
#   Kazuko Uno Bill
#
#
#   Mabel Shoji Boggs
#
#
#   David R. Boyd
#
#
#   Robert "Bob" Bratt
#
#
#   Bill Braye
#
#
#   Nikki Bridges
#
#
#   Harold "Hal" Champeness
#
#
#   Connie Thorson Chandler
#
#
#   Joanne Chiedi
#
#
#   Michiko Frances Chikahisa
#
#
#   Ben Chikaraishi
#
#
#   Ryan Chin
#
#
#   Helen Harano Christ
#
#
#   Diana Morita Cole
#
#
#   Robert Coombs
#
#
#   Patricia Cooper
#
#
#   Tink Cooper
#
#
#   Jack Dairiki
#
#
#   Jun Dairiki
#
#
#   Roger Daniels
#
#
#   Eleanor Davis
#
#
#   Janice Deguchi
#
#
#   Russell Demo
#
#
#   Pam Rouse Dixon
#
#
#   Florence Ohmura Dobashi
#
#
#   Perry Dobashi
#
#
#   Joan Ritchie Doi
#
#
#   Lisa Doi
#
#
#   Roy Doi
#
#
#   Tonko Doi
#
#
#   Yoneko Dozono
#
#
#   Chester Earls
#
#
#   Roy Ebihara
#
#
#   Seiko Edamatsu
#
#
#   Tomiko Hayashida Egashira
#
#
#   Sue K. Embrey
#
#
#   Art Emi
#
#
#   Frank Emi
#
#
#   Chiyo Endo
#
#
#   Kay Endo
#
#
#   Phyllis Fechner
#
#
#   Takayo Tsubouchi Fischer
#
#
#   Michael J. Forrester
#
#
#   Tsuchino Forrester
#
#
#   Joseph Frisino
#
#
#   Bob Fuchigami
#
#
#   George Fugami
#
#
#   Aya Fujii
#
#
#   Ed Fujii
#
#
#   Frank S. Fujii
#
#
#   Susie "Jinx" Fujii
#
#
#   Ann Fujikawa
#
#
#   Ayako Nishi Fujimoto
#
#
#   George Fujimoto
#
#
#   Robert Katsuto Fujioka
#
#
#   Francis Mas Fukuhara
#
#
#   Frank Fukuhara
#
#
#   Henry Fukuhara
#
#
#   Gerald Fukui
#
#
#   Mitsu Fukui
#
#
#   Hanako Hoshiyama Fukumoto
#
#
#   Taira Fukushima
#
#
#   Yuriko Furubayashi
#
#
#   Judy Furuichi
#
#
#   Peggy S. Furukawa
#
#
#   Howard H. Furumoto
#
#
#   Gabrielle Nomura Gainor
#
#
#   Angela Noel Gantt
#
#
#   Kena Gimba
#
#
#   Jean Shiraki Gize
#
#
#   Nancy Nakata Gohata
#
#
#   Kikuno Goi
#
#
#   Mitsuo Goi
#
#
#   Kazie Good
#
#
#   Kenji Goto
#
#
#   Fumiko Uyeda Groves
#
#
#   Marietta Boyd Gruner
#
#
#   Ted Hachiya
#
#
#   Mae Hada
#
#
#   Haruye Murakami Hagiwara
#
#
#   Ted Hamachi
#
#
#   Mary Hamano
#
#
#   Charles Oihe Hamasaki
#
#
#   George Hanada
#
#
#   Geri Handa
#
#
#   Art Hansen
#
#
#   Earl Hanson
#
#
#   George Hara
#
#
#   Mae Kanazawa Hara
#
#
#   Yoneko Hara
#
#
#   Taneyuki Dan Harada
#
#
#   Catherine Embree Harris
#
#
#   Jessie Hatsue Akiyama Okazaki Harry
#
#
#   Junkoh Harui
#
#
#   Mitsuko Hashiguchi
#
#
#   Chikaye Sande Azeka Hashimoto
#
#
#   Mas Hashimoto
#
#
#   Kajiko Hashisaki
#
#
#   Natsuko Hashitani
#
#
#   Bill Hashizume
#
#
#   Grace Hata
#
#
#   Ike Hatchimonji
#
#
#   Clara S. Hattori
#
#
#   Grace Sugita Hawley
#
#
#   John Y. Hayakawa
#
#
#   Lois Hayasaka
#
#
#   Phil Hayasaka
#
#
#   Susan Hayase
#
#
#   Fumi Hayashi
#
#
#   Matsuko Hayashi
#
#
#   Norm Hayashi
#
#
#   Toshiko Hayashi
#
#
#   Fumiko Hayashida
#
#
#   Seichi Hayashida
#
#
#   Elaine Ishikawa Hayes
#
#
#   John "Jack" Herzig
#
#
#   Aiko Herzig-Yoshinaga
#
#
#   Jane Hidaka
#
#
#   Richard Iwao Hidaka
#
#
#   May Ota Higa
#
#
#   Sumiko Higashi
#
#
#   Hatsuko Mary Higuchi
#
#
#   Dan Hinatsu
#
#
#   Massie Hinatsu
#
#
#   Lily C. Hioki
#
#
#   Bill Hirabayashi
#
#
#   Gordon Hirabayashi
#
#
#   Grant Hirabayashi
#
#
#   Hannah Hirabayashi
#
#
#   Jim Hirabayashi
#
#
#   PJ Hirabayashi
#
#
#   Roy M. Hirabayashi
#
#
#   Shyoko Hiraga
#
#
#   Alice Setsuko Sekino Hirai
#
#
#   Izumi Hirano
#
#
#   Fred Hirasuna
#
#
#   Frank H. Hirata
#
#
#   Mary Hirata
#
#
#   Frank Hiratsuka
#
#
#   Margaret Junko Morita Hiratsuka
#
#
#   George Hiromoto
#
#
#   Sachi Hiromoto
#
#
#   Steve Hiromoto
#
#
#   Carol Hirabara Hironaka
#
#
#   Norman I. Hirose
#
#
#   Tokio Hirotaka
#
#
#   Mika Hiuga
#
#
#   William Hohri
#
#
#   Yuriko Hohri
#
#
#   Mutsu Homma
#
#
#   Edward K. Honda
#
#
#   Tamiko Honda
#
#
#   June M. Hoshida Honma
#
#
#   Takashi Hori
#
#
#   Elliot Yoshinobu Horikoshi
#
#
#   Sam Horino
#
#
#   Lillian Horita
#
#
#   Bernadette Suda Horiuchi
#
#
#   Lynne Horiuchi
#
#
#   Lucius Horiuchi
#
#
#   Maynard Horiuchi
#
#
#   Hideo Hoshide
#
#
#   Akio Hoshino
#
#
#   Fred Y. Hoshiyama
#
#
#   Takashi Hoshizaki
#
#
#   Bill Hosokawa
#
#
#   Christie O. Ichikawa
#
#
#   Satoru Ichikawa
#
#
#   Yasashi Ichikawa
#
#
#   Mary Suzuki Ichino
#
#
#   Sumi Ikata
#
#
#   Kay Ikeda
#
#
#   Mary Kinoshita Ikeda
#
#
#   Tom Ikeda
#
#
#   Tsuguo "Ike" Ikeda
#
#
#   Victor Ikeda
#
#
#   Ronald Ikejiri
#
#
#   Dorothy Ikkanda
#
#
#   Tom Ikkanda
#
#
#   Kenji Ima
#
#
#   Art Imagire
#
#
#   Gloria Toshiko Imagire
#
#
#   Shig Imai
#
#
#   Ryo Imamura
#
#
#   Satsuki Ina
#
#
#   Eddie M. Inaba
#
#
#   Lon Inaba
#
#
#   Shiz Inaba
#
#
#   Hiro Heidi Inahara
#
#
#   Toshio Inahara
#
#
#   Yutaka Inokuchi
#
#
#   Daniel Inouye
#
#
#   Ruby Inouye
#
#
#   Shizue Irei
#
#
#   Lilly Kobayashi Irinaga
#
#
#   Taeko Joanne Iritani
#
#
#   Peter Irons
#
#
#   George Iseri
#
#
#   Yasuko Miyoshi Iseri
#
#
#   Art Ishida
#
#
#   Ray Ishii
#
#
#   Joe Ishikawa
#
#
#   Dorothy Michiko Ishimatsu
#
#
#   Sunao "Phil" Ishio
#
#
#   Gary M. Itano
#
#
#   Betty Fumiye Ito
#
#
#   James O. Ito
#
#
#   Mitsu Ito
#
#
#   Susumu Ito
#
#
#   Toshi Nagamori Ito
#
#
#   Toshio Ito
#
#
#   Willie K. Ito
#
#
#   Kazuko Iwahashi
#
#
#   Nancy Iwami
#
#
#   Mary Iwasaki
#
#
#   Susumu Iwasaki
#
#
#   Chizuko Iyama
#
#
#   Ernie Iyama
#
#
#   George Izumi
#
#
#   Toshiro Izumi
#
#
#   Kitako Izumizaki
#
#
#   Pramila Jayapal
#
#
#   Lisa Johnson
#
#
#   James T. Johnston
#
#
#   William R. Johnston
#
#
#   Melvyn Juhler
#
#
#   Shizuko Kadoguchi
#
#
#   Akira Kageyama
#
#
#   Glenn H. Kageyama
#
#
#   Keiko Kageyama
#
#
#   Jane Kaihatsu
#
#
#   Bruce T. Kaji
#
#
#   Frances Midori Tashiro Kaji
#
#
#   Hitoshi H. Kajihara
#
#
#   Jim Kajiwara
#
#
#   Lily Kajiwara
#
#
#   Alice Kale
#
#
#   Isao Kameshige
#
#
#   Noboru Kamibayashi
#
#
#   Yoshiko Kanazawa
#
#
#   John Kanda
#
#
#   Kay Uno Kaneko
#
#
#   Kiyoko Morey Kaneko
#
#
#   William "Bill" Kaneko
#
#
#   Marion Tsutakawa Kanemoto
#
#
#   Sachi Kaneshiro
#
#
#   Miyoko Kaneta
#
#
#   Mary T. Karatsu
#
#
#   Fumi Kaseguma
#
#
#   Shig Kaseguma
#
#
#   Louise Kashino
#
#
#   Genro Kashiwa
#
#
#   Betty Fujimoto Kashiwagi
#
#
#   Hiroshi Kashiwagi
#
#
#   Sadako Nimura Kashiwagi
#
#
#   George Katagiri
#
#
#   Chris Kato
#
#
#   Mary Kato
#
#
#   Michiko Hara Kawaguchi
#
#
#   Harry Kawahara
#
#
#   Dave Kawamoto
#
#
#   Frank S. Kawana
#
#
#   Yukio Kawaratani
#
#
#   Hope Omachi Kawashima
#
#
#   Larry "Shorty" Kazumura
#
#
#   Hiroki Kimiko Keaveney
#
#
#   Daryl Keck
#
#
#   Barbara Reiko Mikami Keimi
#
#
#   Hal Keimi
#
#
#   Shigeo Kihara
#
#
#   Shigeya Kihara
#
#
#   Emiko Namba Kikkawa
#
#
#   Frank Isamu Kikuchi
#
#
#   Isao Kikuchi
#
#
#   George Kikuta
#
#
#   Grace Watanabe Kimura
#
#
#   Robert "Rusty" Kimura
#
#
#   Eugene Tatsuru Kimura
#
#
#   Joe Kino
#
#
#   Ami Kinoshita
#
#
#   Cherry Kinoshita
#
#
#   Kaz Kinoshita
#
#
#   Kyle Kinoshita
#
#
#   Lucy Kirihara
#
#
#   Iku Kiriyama
#
#
#   Masamizu Kitajima
#
#
#   Molly Enta Kitajima
#
#
#   Frank Kitamoto
#
#
#   Shimako "Sally" Kitano
#
#
#   Sox Kitashima
#
#
#   Ted Kitayama
#
#
#   Yoichi "Cannon" Kitayama
#
#
#   Minoru Kiyota
#
#
#   Shoichi Kobara
#
#
#   Kenge Kobayashi
#
#
#   Ryoko Kobayashi
#
#
#   Thomas T. Kobayashi
#
#
#   Yuri Kochiyama
#
#
#   Lilly Kodama
#
#
#   Tats Kojima
#
#
#   Karlene Koketsu
#
#
#   Jane Komeiji
#
#
#   Richard Konda
#
#
#   Kara Kondo
#
#
#   Bessie Yoshida Konishi
#
#
#   Frank Konishi
#
#
#   Gladys Koshio Konishi
#
#
#   Fred Korematsu
#
#
#   Kathryn Korematsu
#
#
#   Michiko Kornhauser
#
#
#   Richard Kosaki
#
#
#   George Koshi
#
#
#   Mits Koshiyama
#
#
#   Nob Koura
#
#
#   Spady Koyama
#
#
#   Sumiko Sakai Kozawa
#
#
#   Mary Okazaki Kozu
#
#
#   Orest Kruhlak
#
#
#   Gloria Kubota
#
#
#   Jack Y. Kubota
#
#
#   Sadaichi Kubota
#
#
#   Emlei "Emi" Kuboyama
#
#
#   Elsa Kudo
#
#
#   Alan Kumamoto
#
#
#   Jan Kumasaka
#
#
#   Jack Y. Kunitomi
#
#
#   Kats Kunitsugu
#
#
#   Tadashi Kuniyuki
#
#
#   Jane Kurahara
#
#
#   Rokuro Kurihara
#
#
#   Ben Kuroki
#
#
#   Shige Kuroki
#
#
#   Yosh Kuromiya
#
#
#   Akiko Kurose
#
#
#   Paul Kurose
#
#
#   Ruthann Kurose
#
#
#   Marian Asao Kurosu
#
#
#   Jun Kurumada
#
#
#   Tommy T. Kushi
#
#
#   Sat Kuwamoto
#
#
#   Dorothy Kuwaye
#
#
#   Hannah Lai
#
#
#   Ann Fujii Lindwall
#
#
#   Yukiko Llewellyn
#
#
#   James Lovell
#
#
#   Barbara Lui
#
#
#   Angus Macbeth
#
#
#   Arnold T. Maeda
#
#
#   Don Maeda
#
#
#   George Maeda
#
#
#   Molly K. Maeda
#
#
#   Sharon Maeda
#
#
#   Ron Magden
#
#
#   Yoshi Mamiya
#
#
#   Helen Amerman Manning
#
#
#   Kenji Maruko
#
#
#   John Kats Marumoto
#
#
#   William Marutani
#
#
#   Dave T. Maruya
#
#
#   Kiyo Maruyama
#
#
#   Marion I. Masada
#
#
#   Saburo Masada
#
#
#   Amy Iwasaki Mass
#
#
#   Kiyoko Masuda
#
#
#   Nori Masuda
#
#
#   Harriet Sato Masunaga
#
#
#   Charlie Matsubara
#
#
#   Mary Matsubara
#
#
#   Jimmie S. Matsuda
#
#
#   Hisa Matsudaira
#
#
#   George S. Matsui
#
#
#   Mitsue Matsui
#
#
#   Takashi Matsui
#
#
#   Akemi Matsumoto
#
#
#   George Matsumoto
#
#
#   Jean Matsumoto
#
#
#   Roy H. Matsumoto
#
#
#   Yoshio Matsumoto
#
#
#   Fred Matsumura
#
#
#   Spark M. Matsunaga
#
#
#   David Matsuoka
#
#
#   Jim Matsuoka
#
#
#   Kay Matsuoka
#
#
#   Tom Matsuoka
#
#
#   Walter N. Matsuoka
#
#
#   Yoji J. Matsushima
#
#
#   Yoshimi Matsuura
#
#
#   Mae Matsuzaki
#
#
#   Joe Matsuzawa
#
#
#   James C. McNaughton
#
#
#   Aya Uenishi Medrud
#
#
#   Mara Mihara
#
#
#   Sam Mihara
#
#
#   Katsugo Miho
#
#
#   Peggy Yamato Mikuni
#
#
#   Mary Jane Mikuriya
#
#
#   Dale Minami
#
#
#   Takeshi Minato
#
#
#   Tom I. Mine
#
#
#   Helene J. Minehira
#
#
#   Norman Mineta
#
#
#   Janice Mirikitani
#
#
#   Nellie Mitani
#
#
#   Edward H. Mitsukado
#
#
#   Rin Miura
#
#
#   Alfred "Al" Miyagishima
#
#
#   Nancy Sawada Miyagishima
#
#
#   Yukiko Miyahara
#
#
#   Yukiko Miyake
#
#
#   Nobuko Miyake-Stoner
#
#
#   Shig Miyaki
#
#
#   Frank Miyamoto
#
#
#   Herbert Y. Miyasaki
#
#
#   Archie Miyatake
#
#
#   Henry Miyatake
#
#
#   Kazuko Miyoshi
#
#
#   Taka Mizote
#
#
#   Robert Mizukami
#
#
#   Junko Mizuta
#
#
#   Yoshito Mizuta
#
#
#   Yasu Koyamatsu Momii
#
#
#   Emily Momohara
#
#
#   Mary Montoya
#
#
#   Osamu Mori
#
#
#   Ramsay Yosuke Mori
#
#
#   Helen Mori
#
#
#   Robert Moriguchi
#
#
#   Tomio Moriguchi
#
#
#   George Morihiro
#
#
#   Kiyo Nikaido Morimoto
#
#
#   George H. Morishita
#
#
#   Shig Moritani
#
#
#   Tatsukichi Moritani
#
#
#   Toshio Moritsugu
#
#
#   Hikaru Morohoshi
#
#
#   Susumu Mukushina
#
#
#   Ayako Murakami
#
#
#   George Murakami
#
#
#   Judy Murakami
#
#
#   Masako Murakami
#
#
#   Masako Murakami
#
#
#   Richard Murakami
#
#
#   Richard M. Murakami
#
#
#   Roy Murakami
#
#
#   Frank Muramatsu
#
#
#   Mike Murase
#
#
#   Take Murayama
#
#
#   Peggy A. Nagae
#
#
#   Fred Nagai
#
#
#   Miyoko Sakai Nagai
#
#
#   Paul Nagano
#
#
#   George Kazuharu Naganuma
#
#
#   Jimmy Naganuma
#
#
#   Kazumu Naganuma
#
#
#   Ted Nagata
#
#
#   Hitoshi "Hank" Naito
#
#
#   Marian Uyematsu Naito
#
#
#   Sam Naito
#
#
#   Irene Najima
#
#
#   John Nakada
#
#
#   Giro Nakagawa
#
#
#   Mako Nakagawa
#
#
#   Mark M. Nakagawa
#
#
#   Miyoko Tsuboi Nakagawa
#
#
#   Roy Nakagawa
#
#
#   Yosh Nakagawa
#
#
#   Rose Nakagawa
#
#
#   Masahiro Nakajo
#
#
#   Grace Shinoda Nakamura
#
#
#   Mary Haruka Nakamura
#
#
#   Robert A. Nakamura
#
#
#   Tetsujiro "Tex" Nakamura
#
#
#   Yosh Nakamura
#
#
#   Susumu Nakanishi
#
#
#   Bert Nakano
#
#
#   George Nakano
#
#
#   Henry Nakano
#
#
#   Hiroshi Nakano
#
#
#   James A. Nakano
#
#
#   Kenichi Nakano
#
#
#   Lillian Nakano
#
#
#   Stanley Nakano
#
#
#   Yaeko Nakano
#
#
#   Isami Nakao
#
#
#   Kazuko Nakao
#
#
#   Mollie Nakasaki
#
#
#   Hiroko Nakashima
#
#
#   Kimiko Nakashima
#
#
#   George Nakata
#
#
#   Gerald Nakata
#
#
#   Tatsuo Nakata
#
#
#   Takeshi Nakayama
#
#
#   May Y. Namba
#
#
#   Kenneth Narahara
#
#
#   Rose Niguma
#
#
#   Flora Ninomiya
#
#
#   Frances Kajita Nishi
#
#
#   Henry Nishi
#
#
#   Nancy Nishi
#
#
#   Mo Nishida
#
#
#   Eiko Nishihara
#
#
#   Yoshiko Nishihara
#
#
#   Arthur Nishimoto
#
#
#   Bill Nishimura
#
#
#   Hiro Nishimura
#
#
#   James Nishimura
#
#
#   Ko Nishimura
#
#
#   Alan Nishio
#
#
#   Esther Takei Nishio
#
#
#   Mitsue Nishio
#
#
#   Alice Nishitani
#
#
#   Martha Nishitani
#
#
#   Doris Nitta
#
#
#   Ujinobu Niwa
#
#
#   Yoshino Grace Fukuhara Niwa
#
#
#   Andy Noguchi
#
#
#   Thomas T. Noguchi
#
#
#   Fumiko M. Noji
#
#
#   Tetsuo Nomiyama
#
#
#   Mary Kageyama Nomura
#
#
#   Shoso "Sho" Nomura
#
#
#   Michiko Amatatsu Noritake
#
#
#   Chizuko Norton
#
#
#   Kay Ochi
#
#
#   Rose Matsui Ochi
#
#
#   Fred Oda
#
#
#   George Oda
#
#
#   Nancy Kyoko Oda
#
#
#   Arthur Ogami
#
#
#   Kimi Ogami
#
#
#   Kenji Ogawa
#
#
#   Jun Ogimachi
#
#
#   Sam Ogo
#
#
#   Marian A. Ohashi
#
#
#   Robert T. Ohashi
#
#
#   Don Oka
#
#
#   Shig Oka
#
#
#   Mas Okabe
#
#
#   Shirley Nagatomi Okabe
#
#
#   Sue Takimoto Okabe
#
#
#   Katsumi Okamoto
#
#
#   Sachiye Okamoto
#
#
#   Sumi Okamoto
#
#
#   Toshikazu "Tosh" Okamoto
#
#
#   Kinge Okauchi
#
#
#   Joyce Okazaki
#
#
#   Kato Okazaki
#
#
#   Arlene Oki
#
#
#   Ruth Y. Okimoto
#
#
#   Fred Okrand
#
#
#   Don Okubo
#
#
#   Mas Okui
#
#
#   Kenneth Okuma
#
#
#   Toyoko Okumura
#
#
#   Akiko Okuno
#
#
#   Art Okuno
#
#
#   Charles Olds
#
#
#   Chiyoko Chiyo Omachi
#
#
#   Frank K. Omatsu
#
#
#   Chizuko Omori
#
#
#   Nobuko Omoto
#
#
#   Sadayoshi Omoto
#
#
#   Taketo Omoto
#
#
#   Yukiko Katayama Omoto
#
#
#   James Omura
#
#
#   Jim Onchi
#
#
#   Keith One
#
#
#   Kenji Onishi
#
#
#   Muriel Chiyo Tanaka Onishi
#
#
#   Richard Onishi
#
#
#   Sam H. Ono
#
#
#   Joanne F. Oppenheim
#
#
#   Elsie Uyematsu Osajima
#
#
#   Ron Osajima
#
#
#   Etsuko Ichikawa Osaki
#
#
#   Isao East Oshima
#
#
#   Susumu Oshima
#
#
#   Grace F. Oshita
#
#
#   Frances Ota
#
#
#   Akira Otani
#
#
#   Kunio Otani
#
#
#   Makoto Otsu
#
#
#   Julie Otsuka
#
#
#   Bennie Ouchida
#
#
#   Eddie Owada
#
#
#   Albert A. Oyama
#
#
#   Masuko Oyama
#
#
#   Atsumi Ozawa
#
#
#   Larry R. Pacheco
#
#
#   Frances Sumida Palk
#
#
#   HyeEun Park
#
#
#   Susan Brown Phelps
#
#
#   Kerry Christenson Powell
#
#
#   Chizuko Judy Sugita de Quieiroz
#
#
#   Doreen Rapada
#
#
#   Dotti Yasuko Tagawa Reisbord
#
#
#   Edwin "Ed" L. Rothfuss
#
#
#   Mika Kurose Ruthann
#
#
#   Kanji Sahara
#
#
#   Barry Saiki
#
#
#   Joe Saito
#
#
#   Margaret Saito
#
#
#   Paul Saito
#
#
#   Sumi Saito
#
#
#   Toru Saito
#
#
#   Bo T. Sakaguchi
#
#
#   Kiyo Sakahara
#
#
#   Toru Sakahara
#
#
#   Hisaji Q. Sakai
#
#
#   Lawson I. Sakai
#
#
#   Shiuko Sakai
#
#
#   Shizuko "Suzie" Sakai
#
#
#   Annie Sakamoto
#
#
#   Henry Sakamoto
#
#
#   James Sakamoto
#
#
#   Janice Sakamoto
#
#
#   Patricia Mariko Morikawa Sakamoto
#
#
#   Bob Y. Sakata
#
#
#   Toshiko Sakata
#
#
#   Bacon Sakatani
#
#
#   George T. "Joe" Sakato
#
#
#   Eiichi Edward Sakauye
#
#
#   Heidi Sakazaki
#
#
#   Tadashi Sakuma
#
#
#   David Sakura
#
#
#   Richard Sakurai
#
#
#   Jack Sameshima
#
#
#   Iwao Peter Sano
#
#
#   Bob Santos
#
#
#   Rep. Sharon Tomiko Santos
#
#
#   Junji Sarashina
#
#
#   Laurie Sasaki
#
#
#   May K. Sasaki
#
#
#   Ruth Sasaki
#
#
#   Shosuke Sasaki
#
#
#   Frank T. Sata
#
#
#   Marian Shingu Sata
#
#
#   Dorothy H. Sato
#
#
#   Frank Sato
#
#
#   Lillian Sato
#
#
#   Lury Sato
#
#
#   Maria Sato
#
#
#   Rick Sato
#
#
#   Sarah Sato
#
#
#   Tad Sato
#
#
#   Wilbur Sato
#
#
#   Paul Satoh
#
#
#   Floyd Schmoe
#
#
#   Mary Schroeder
#
#
#   Sharon Seeder
#
#
#   Randy Senzaki
#
#
#   Grace K. Seto
#
#
#   Joe Seto
#
#
#   Sharon Sobie Seymour
#
#
#   Hana Shepard
#
#
#   Minoru J. Shibata
#
#
#   Art Shibayama
#
#
#   Betty Morita Shibayama
#
#
#   Eiko Shibayama
#
#
#   Zen Shibayama
#
#
#   Yo Shibuya
#
#
#   Joy Shigaki
#
#
#   Misako Shigekawa
#
#
#   Phil Shigekuni
#
#
#   Thomas Shigekuni
#
#
#   Lois Shikami
#
#
#   Stanley N. Shikuma
#
#
#   Fumie I. Shimada
#
#
#   Kay Shimada
#
#
#   Henry Shimizu
#
#
#   Cedrick M. Shimo
#
#
#   Nobu Shimokochi
#
#
#   Floyd Shimomura
#
#
#   Roger Shimomura
#
#
#   Nancy Shimotsu
#
#
#   Fred Tadashi Shingu
#
#
#   Keiko Shinmoto
#
#
#   Rick Shiomi
#
#
#   Fred Shiosaki
#
#
#   Miho Shiroishi
#
#
#   Beth Shironaka
#
#
#   Kazuo Shiroyama
#
#
#   Bill Hiroshi Shishima
#
#
#   Hy Shishino
#
#
#   Martha Shoaf
#
#
#   Alice Abrams Siegal
#
#
#   Mary Blocher Smeltzer
#
#
#   Charles Z. Smith
#
#
#   Gus J. Solomon
#
#
#   Emi Somekawa
#
#
#   Mary Jean Spallino
#
#
#   Marjorie Matsushita Sperling
#
#
#   Joy Misako S. Germain
#
#
#   Margaret Stanicci
#
#
#   Elaine Clary Stanley
#
#
#   Sally Sudo
#
#
#   Kenji Suematsu
#
#
#   Jiro Sugidono
#
#
#   Ann Sugimoto
#
#
#   Shigeki Sugiyama
#
#
#   Alice E. Sumida
#
#
#   Frank Sumida
#
#
#   Marshall M. Sumida
#
#
#   Akio Suyematsu
#
#
#   Yoshimitsu Suyematsu
#
#
#   Bob Suzuki
#
#
#   James "Turk" Suzuki
#
#
#   Midori Suzuki
#
#
#   Nobu Suzuki
#
#
#   Warren Koichi Suzuki
#
#
#   John A. (Jack) Svahn
#
#
#   Kay Sweeney
#
#
#   Kan Tagami
#
#
#   Kenji Taguma
#
#
#   Mii Tai
#
#
#   Minoru Tajii
#
#
#   Paul Takagi
#
#
#   Sanzui A. Takaha
#
#
#   June Takahashi
#
#
#   Mits Takahashi
#
#
#   Yukiko Takahashi
#
#
#   Roy Takai
#
#
#   Mas Takano
#
#
#   Jo Takata
#
#
#   M. Jack Takayanagi
#
#
#   Mary Takayanagi
#
#
#   Joe Takehara
#
#
#   Rae Takekawa
#
#
#   Bill Takemoto
#
#
#   Victor Takemoto
#
#
#   Sumiye Takeno
#
#
#   Ben Takeshita
#
#
#   Carolyn Takeshita
#
#
#   Cookie Takeshita
#
#
#   Helen Takeshita
#
#
#   Misa Taketa
#
#
#   Hikoji Takeuchi
#
#
#   Hiro Takeuchi
#
#
#   Tomiko Takeuchi
#
#
#   Donald K. Tamaki
#
#
#   Ben Tamashiro
#
#
#   Frank Shinichiro Tanabe
#
#
#   Gus Tanaka
#
#
#   Chester Tanaka
#
#
#   Kyoko Nishi Tanaka
#
#
#   Rose Tanaka
#
#
#   Taketora Jim Tanaka
#
#
#   Walter Tanaka
#
#
#   Betty Tanakatsubo
#
#
#   Kaz T. Tanemura
#
#
#   Peggy Tanemura
#
#
#   Setsu Tsuboi Tanemura
#
#
#   Jim M. Tanimoto
#
#
#   Kazue Murakami Tanimoto
#
#
#   Bill Tashima
#
#
#   John Tateishi
#
#
#   Dave Tatsuno
#
#
#   Irene Yamauchi Tatsuta
#
#
#   Clyde Taylor
#
#
#   Elmer Tazuma
#
#
#   Celeste Teodor
#
#
#   Hiroshi Terry Terakawa
#
#
#   Kay Teramura
#
#
#   Asano Terao
#
#
#   Tomiye Terasaki
#
#
#   Bill Thompson
#
#
#   Clyde Tichenor
#
#
#   Takeko Yokoyama Todo
#
#
#   Evelyn Togami
#
#
#   Rudy Tokiwa
#
#
#   Kip Tokuda
#
#
#   Aiko Tengan Tokunaga
#
#
#   Tosh Tokunaga
#
#
#   Chiye Tomihiro
#
#
#   Kenji Tomita
#
#
#   Mary Nakata Tomita
#
#
#   John Tomita
#
#
#   Taylor Tomita
#
#
#   Min Tonai
#
#
#   Ben Y. Tonooka
#
#
#   Minoru "Min" Tsubota
#
#
#   Kiwamu "Kiyo" Tsuchida
#
#
#   Helen Tanigawa Tsuchiya
#
#
#   Fumino Tsuchiya-Knox
#
#
#   Amy Tsugawa
#
#
#   George Tsugawa
#
#
#   Jim Tsugawa
#
#
#   Jim Tsujimura
#
#
#   Ted Tsukiyama
#
#
#   Paul Tsuneishi
#
#
#   Rose Ito Tsunekawa
#
#
#   Ayako Tsurutani
#
#
#   Ayame Tsutakawa
#
#
#   Ed Tsutakawa
#
#
#   Heidi Tsutakawa
#
#
#   Mayumi Tsutakawa
#
#
#   Kenzan Tsutakawa-Chinn
#
#
#   Yayoi Tsutakawa-Chinn
#
#
#   George Uchida
#
#
#   Leo Uchida
#
#
#   Yoshihiro Uchida
#
#
#   Joseph Norio Uemura
#
#
#   Atami Ueno
#
#
#   Harry Ueno
#
#
#   Henry Ueno
#
#
#   Grant Ujifusa
#
#
#   Harry Umeda
#
#
#   Hank Shozo Umemoto
#
#
#   Ernest Uno
#
#
#   Shigeko Sese Uno
#
#
#   Miyo Minnie Uratsu
#
#
#   Tetsushi Marvin Uratsu
#
#
#   Bob Utsumi
#
#
#   Chico Uyeda
#
#
#   Clifford Uyeda
#
#
#   Sumi Uyeda
#
#
#   Grayce Uyehara
#
#
#   Hiroshi Uyehara
#
#
#   Roy Uyehata
#
#
#   Amy Uyematsu
#
#
#   Ben Uyeno
#
#
#   Miyoko Uzaki
#
#
#   Michiko Wada
#
#
#   Robert M. Wada
#
#
#   Yae Wada
#
#
#   Kimi Wakabayashi
#
#
#   Ron Wakabayashi
#
#
#   John Wakamatsu
#
#
#   Yooichi Wakamiya
#
#
#   George Kiyo Wakatsuki
#
#
#   Lloyd K. Wake
#
#
#   Takae Tanino Walts
#
#
#   Alley Watada
#
#
#   Ehren Watada
#
#
#   Yoshimi Hasui Watada
#
#
#   Anne Yuki Watanabe
#
#
#   Edith Watanabe
#
#
#   Harvey Watanabe
#
#
#   Iku Amatatsu Watanabe
#
#
#   June T. Watanabe
#
#
#   Louie Watanabe
#
#
#   Martha Watanabe
#
#
#   Mary Ishimoto Watanabe
#
#
#   Masao Watanabe
#
#
#   Matsue Watanabe
#
#
#   May Ohmura Watanabe
#
#
#   Warren H. Watanabe
#
#
#   Wesley K. Watanabe
#
#
#   Bill Watanabe
#
#
#   Ellen Watanabe-Huxtable
#
#
#   Michi Weglyn
#
#
#   Jane Wehrey
#
#
#   Marianne West
#
#
#   Virgil W. Westdale
#
#
#   Dorothy J. Whitlock
#
#
#   Margie Y. Wong
#
#
#   Mary Woodward
#
#
#   Walt Woodward
#
#
#   Shig Yabu
#
#
#   Chiyoko Yagi
#
#
#   Kan Yagi
#
#
#   Kenji J. Yaguchi
#
#
#   George Yamada
#
#
#   Gordon Yamada
#
#
#   Henry Bruno Yamada
#
#
#   Mae Iseri Yamada
#
#
#   Mitsuye May Yamada
#
#
#   Gary Yamagiwa
#
#
#   Kathy Yamaguchi
#
#
#   Minoru Yamaguchi
#
#
#   Eiko Yamaichi
#
#
#   Jimi Yamaichi
#
#
#   Joe Yamakido
#
#
#   Donald Yamamoto
#
#
#   Emi Yamamoto
#
#
#   Eric K. Yamamoto
#
#
#   Fusako Yamamoto
#
#
#   Hisaye Yamamoto
#
#
#   Kaz Yamamoto
#
#
#   Kazue Yamamoto
#
#
#   Madelon Arai Yamamoto
#
#
#   Richard H. Yamamoto
#
#
#   Steve Yamamoto
#
#
#   Sumiko M. Yamamoto
#
#
#   Takenori Yamamoto
#
#
#   Yoneo Yamamoto
#
#
#   Yuriko Yamamoto
#
#
#   K. Morgan Yamanaka
#
#
#   Kazuo Yamane
#
#
#   Tokio Yamane
#
#
#   Frank Yamasaki
#
#
#   Mits Yamasaki
#
#
#   Maurice H. Yamasato
#
#
#   Constance Yamashiro
#
#
#   Richard E. Yamashiro
#
#
#   Eiichi Yamashita
#
#
#   Isao Yamashita
#
#
#   Kiyoshi Seishin Yamashita
#
#
#   Tak Yamashita
#
#
#   Sumiko Yamauchi
#
#
#   Wakako Yamauchi
#
#
#   James Yamazaki
#
#
#   Paul Yamazaki
#
#
#   Chiyoko Yano
#
#
#   David Yano
#
#
#   George Yano
#
#
#   Yoshiye Handa Yasuda
#
#
#   Homer Yasui
#
#
#   Minoru Yasui
#
#
#   Miyuki Yasui
#
#
#   Joe Yasutake
#
#
#   Tosh Yasutake
#
#
#   Kay Yatabe
#
#
#   Grace Kubota Ybarra
#
#
#   Paul Yempuku
#
#
#   Susumu Yenokida
#
#
#   Wally Yonamine
#
#
#   Kazumi Yoneyama
#
#
#   George Yoshida
#
#
#   Hubert Yoshida
#
#
#   Ken Yoshida
#
#
#   Mary T. Yoshida
#
#
#   Masako Yoshida
#
#
#   Yaeko Yoshihara
#
#
#   Ed Yoshikawa
#
#
#   Harry K. Yoshikawa
#
#
#   Pearl Yoshikawa
#
#
#   Kiyo Yoshimura
#
#
#   George Yoshinaga
#
#
#   George M. Yoshino
#
#
#   Karen Yoshitomi
#
#
#   John Young
#
#
#   Sharon Yuen
#
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# HTTP Error 500: Internal Server Error
#
#   Lois Yuki
#
#
#   Aaron Zajic
#
# Mounted at drive
# Completed in --- 725.2945883274078 seconds ---

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
import pandas as pd
import io
from google.colab import drive
from nltk.corpus import stopwords
import nltk
import string
import re

nltk.download('stopwords')
nltk.download('punkt')

#load the csv back to Colab
drive.mount('drive', force_remount=True)

dataframe = pd.read_csv('/content/drive/My Drive/densho_11700380.csv')

#combine the name and the desc
dataframe['desc'] = dataframe['name'] +" "+ dataframe['desc']

#1 remove noise special characters and punctuations
dataframe['desc'] = dataframe['desc'].str.replace("[^A-Za-z]+"," ")

#2 remove number
dataframe['desc'] = dataframe['desc'].str.replace("[0-9]+"," ")

#3 remove stopwords
stop = stopwords.words('english')
dataframe['desc'] = dataframe['desc'].apply(lambda x: " ".join(x for x in str(x).split() if x not in stop))

#4 lowercase all texts
dataframe['desc'] = dataframe['desc'].str.lower()

#5 stemming
from nltk.stem import PorterStemmer
st = PorterStemmer()
dataframe['desc'] = dataframe['desc'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

#6 lemmatization
from textblob import Word
import nltk
nltk.download('wordnet')

dataframe['desc'] = dataframe['desc'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

dataframe.to_csv('/content/drive/My Drive/densho_11700380_cleaned.csv', encoding='utf-8')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Mounted at drive
# <ipython-input-5-86707404f54f>:22: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe['desc'] = dataframe['desc'].str.replace("[^A-Za-z]+"," ")
# <ipython-input-5-86707404f54f>:25: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe['desc'] = dataframe['desc'].str.replace("[0-9]+"," ")
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here
#1 POS tagging
# !pip install stanza
import pandas as pd
import nltk
import stanza
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize

import spacy

from collections import Counter

from google.colab import drive

nltk.download('averaged_perceptron_tagger')

#combine all rows to one single string
big_string = " ".join(dataframe['desc'])

print(Counter([j for i,j in pos_tag(word_tokenize(big_string))]))

nlp = spacy.load('en_core_web_sm')


#2 Constituency Parsing and Dependency Parsing
#Constituency Parsing
print("------Constituency Parsing------")

const = stanza.Pipeline(lang='en', processors='tokenize,pos,constituency')

for sents in dataframe['desc']:
  doc = const(sents)

  for sentence in doc.sentences:
    print(sentence.constituency)

#Dependency Parsing
print("------Dependency Parsing------")
for sents in dataframe['desc']:
  doc_1 = nlp(sents)

  for chunk in doc_1.noun_chunks:
    print(chunk.text, chunk.root.text, chunk.root.dep_,
            chunk.root.head.text)


#3 Named Entity Recognition
print("------Named Entity Recognition------")
text = []
label = []

doc_2 = nlp(big_string)

for ent in doc_2.ents:
  text.append(ent.text)
  label.append(ent.label_)

entities = pd.DataFrame({"text": text, "label": label})
entities = entities.groupby(['text','label'])['text'].count()

entities.head()
# Out:
# Requirement already satisfied: stanza in /usr/local/lib/python3.10/dist-packages (1.8.0)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from stanza) (2.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.25.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.2.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Counter({'NN': 31883, 'JJ': 9272, 'VBD': 1746, 'IN': 1626, 'VBP': 1607, 'VBN': 937, 'NNS': 899, 'RB': 814, 'VB': 561, 'VBZ': 268, 'CD': 245, 'FW': 217, 'DT': 147, 'PRP': 123, 'MD': 103, 'NNP': 91, 'JJR': 66, 'JJS': 62, 'CC': 52, 'RBR': 34, 'WRB': 27, 'RP': 20, 'PRP$': 14, 'VBG': 14, 'WP': 7, 'WP$': 5, 'RBS': 4, 'WDT': 2, 'TO': 2, 'PDT': 1, 'UH': 1})
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ------Constituency Parsing------
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# WARNING:stanza:Language en package default expects mwt, which has been added
# INFO:stanza:Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | constituency | ptb3-revised_charlm |
# ======================================
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: constituency
# INFO:stanza:Done loading processors!
# (ROOT (S (NP (NML (NNP kay) (NN aiko)) (NNP abe) (NNP nisei) (NNP femal) (VBN born)) (VP (MD may) (S (NP (NNP selleck) (SBAR (S (NP (NNP washington)) (VP (VBD spent) (NP (JJ much) (NN childhood) (NML (NML (NNP beaverton) (NNP oregon) (NN father)) (JJ own)) (NML (NN farm) (NN influenc)) (JJ earli) (NN age) (NN parent)))))) (VP (VP (VBZ convers)) (NP (NML (JJ christian) (NNP dure)) (NN world) (NN war)) (ADVP (NNP ii)) (VP (VB remov) (NP (NML (NNP portland) (NN assembl) (NN center)) (NNP oregon) (NNP minidoka) (NN concentr) (NN camp) (NNP idaho)) (SBAR (IN after) (S (NP (NN war) (NN work)) (VP (VBP establish) (NP (NP (NN success) (NN volunt) (NN program)) (VP (NN feed) (NP (JJ homeless) (NN seattl) (NNP washington)))))))))))))
# (ROOT (S (NP (NML (NN art) (NNP abe)) (NNP nisei) (ADJP (JJ male) (VBN born)) (NML (NNP june) (NNP seattl)) (NML (NNP washington))) (VP (VBD grew) (NP (NP (ADJP (NP (NN area) (NN seattl) (FW japanes)) (JJ american) (VB attend)) (NN univers) (NNP washington) (NML (NML (NNP japan) (NN bomb)) (NN pearl)) (NN harbor)) (NN remov) (NP (NML (NNP puyallup) (NN assembl) (NN center)) (NNP washington) (NN minidoka) (NN concentr) (NN camp) (NN idaho) (VBN left) (NN minidoka) (NN sever) (NN time) (NML (JJ temporari) (NN work)) (NN leav) (NN work) (NN farm) (NN area) (VP (VB suffer) (S (NP (JJ tragic) (NN loss) (NN camp) (NN father)) (VP (VBD got) (ADJP (VBN lost) (PP (IN outsid) (S (VP (VB collect) (NP (NML (NML (NN wood) (NN perish)) (NN element) (NN volunt) (FW armi) (NN serv) (NN signal) (NN corp) (NN eventu) (NN work)) (JJ civil) (NN aeronaut) (NN administr) (NNP boe)) (ADVP (RB also)) (NP (CD one) (NML (JJ earli) (NN member)) (NN seattl) (NNP nisei) (NN veteran) (NN committe))))))))))))))
# (ROOT (NML (NNP sharon) (FW tanagi) (FW aburano) (FW nisei) (FW femal) (VBN born) (FW octob) (FW seattl) (NNP washington) (FW famili) (JJ own) (NML (NN oper) (NN success)) (NML (NNP groceri) (NN store)) (NML (JJ prior) (NN world)) (NN war) (ADVP (NNP ii)) (SBAR (IN after) (S (NP (NML (NN bomb) (NN pearl)) (NN harbor)) (VP (VBD remov) (NP (NML (NML (NNP puyallup) (NN assembl) (NN center)) (NNP washington) (NNP minidoka) (NN concentr) (NN camp) (NNP idaho)) (VBN left) (NN camp))))) (VP (VB attend) (NP (NP (NP (NML (NNP st) (NML (NML (NNP mari) (NN school)) (NN nurs)) (JJ rochest)) (NNP minnesota) (NN work) (NN medic) (NN field)) (NNP minnesota)) (NNP seattl) (FW eventu) (FW pursu) (NP (NN career) (NN educ))))))
# (ROOT (S (NP (NP (NML (NNP toshiko) (NNP aiboshi) (NNP nisei)) (ADJP (NNP femal) (VBN born)) (NML (NML (NNP juli) (NNP boyl)) (NN height)) (NNP california)) (PP (IN at) (NP (JJ earli) (NN age)))) (VP (VBD went) (ADVP (NP (ADJP (JJ live) (JJ famili) (NN friend)) (NN father) (FW pas)) (RB away)) (S (NP (NML (NN mother) (NN contract)) (NN tuburculosi) (NNP dure) (NN world) (NN war) (NNP ii)) (VP (NNP remov) (NP (NNP santa) (FW anita) (NML (NN assembl) (NN center)) (NNP california) (NNP granada) (NNP amach) (NML (NNP concentr) (NN camp)) (NNP colorado)) (SBAR (IN while) (S (S (NP (NN camp) (NN mother)) (VP (VBZ relaps) (NP (NNP toshiko)))) (VP (VBD went) (NP (JJ live) (JJ famili) (NN friend)) (PP (IN after) (NP (NML (NN war) (NN return)) (NNP california)))))))))))
# (ROOT (S (S (NML (NNP dougla) (NNP l) (NNP aihara) (NNP sansei) (ADJP (NNP male) (VBN born)) (NNP march) (FW torranc) (FW california)) (VP (FW grew) (NP (NP (NML (NML (FW lo) (FW angel)) (FW area)) (FW father)) (VP (FW sold) (S (NP (FW insur) (FW activ) (FW lo) (FW angel) (FW koyasan) (FW buddhist) (FW templ) (FW boy) (FW scout) (FW troop) (FW perform) (FW drum) (FW bugl) (FW corp))))))) (VP (FW attend) (S (NP (FW ucla) (FW join) (FW staff) (FW gidra) (FW asian) (FW american) (FW monthli) (FW newspap) (FW magazin) (FW start) (FW group) (FW student) (FW eventu)))) (VP (VBD took) (NP (NN father) (NNP insur) (FW busi)))))
# (ROOT (S (S (NP (NML (FW yae) (FW aihara)) (FW nisei) (NML (NML (FW femal) (FW born) (FW august) (FW tacoma)) (FW washington)) (FW rais) (FW seattl) (FW washington) (FW famili) (FW oper) (NNP groceri) (FW store)) (VP (VBD attend) (NML (NML (NNP washington) (NNP grammar) (FW school)) (NNP garfield) (JJ high) (FW school) (FW seattl) (VP (FW follow) (NML (NML (FW bomb) (NNP pearl)) (NNP harbor) (NN father) (NN arrest))) (NML (NNP fbi))))) (VP (VBD sent) (NML (NNP missoula) (FW intern) (NNP camp) (FW montana) (FW famili) (FW remov) (NML (NNP puyallup) (FW assembl) (FW center)) (NNP washington) (NNP minidoka) (NNP concentr) (FW camp) (NNP idaho)) (PP (IN in) (NP (NN father) (NNP decid) (NNP repatri) (NNP japan))) (NP (NP (DT the) (NML (NML (NN famili) (NN transport)) (NNP elli) (NN island)) (NN detent) (NN station)) (VP (NN reunit) (NP (NML (NN father) (NN board)) (NML (NML (NN repatri) (NN ship)) (POS s)) (NML (NML (NML (NN gripsholm) (NN transfer)) (NN crystal)) (NN citi)) (NML (NML (NN intern) (NN camp)) (NN texa)) (NNP deni) (NNP entri) (POS s) (S (NP (NNP gripsholm)) (VP (VBP remain) (NP (NN crystal) (NNP citi) (NN durat) (NN war) (NN resettl) (NNP boyl) (NN height) (NN neighborhood) (JJ lo) (NN angel))))))))))
# (ROOT (ADJP (VP (FW elain) (FW akagi)) (PP (FW in) (NP (FW session) (FW elain) (ADJP (FW kim) (FW led)) (NML (FW panel) (FW elain)) (FW reiko) (FW akagi) (FW friend) (NML (FW ann) (FW fujii) (FW lindwal) (FW arlen)) (FW oki) (FW karen) (FW yoshitomi) (FW bill) (FW tashima) (FW remembr) (FW convers) (NML (FW akagi) (FW elain)) (FW reiko) (FW akagi) (FW devot) (FW life) (FW jacl) (FW teach) (FW child) (FW special) (FW educ) (FW need) (FW love) (FW anim) (NP (FW she) (FW activ) (FW detroit) (FW jr) (FW jacl) (FW earli)) (VP (FW led) (NP (NNP detroit) (FW chapter) (FW action) (NML (NML (FW vincent) (FW chin)) (FW murder)) (FW detroit) (NML (FW after) (FW move)) (FW seattl) (FW akagi) (FW becam) (FW chapter) (FW presid) (FW akagi) (CD one) (FW chapter) (FW leader) (FW initi) (FW teacher) (FW workshop) (FW instruct) (NN teacher) (NN method) (FW teach) (FW lesson) (FW ja) (FW wwii) (FW classroom) (FW instil) (FW critic) (FW think) (FW student) (FW appli) (FW lesson) (FW current) (FW day) (FW issu) (NML (FW akagi) (FW endow)) (FW chapter) (FW scholarship) (FW primari) (FW purpos) (FW encourag) (FW student) (FW color) (FW go) (FW field) (FW special) (FW educ) (FW akagi) (FW firm) (FW believ) (FW child) (FW educ) (FW enhanc) (FW teacher) (FW look) (UH like)))))))
# (ROOT (S (S (NP (NML (FW nelson) (FW takeo) (FW akagi)) (FW nisei) (NML (NML (FW male) (FW born)) (FW juli) (FW lindsay)) (FW california)) (VP (FW follow) (NML (NML (FW bomb) (FW pearl) (FW harbor)) (FW move) (FW famili) (NNP idaho) (FW voluntari) (FW evacu) (NN work) (NN harvest) (NN sugar) (FW beet)))) (FW u) (FW i) (NP (NP (NN sugar) (FW compani)) (FW volunt) (FW armi) (NN world) (NN war) (NNP ii) (NNP serv) (NNP nd) (NN field) (NN artilleri) (NN battalion) (ADJP (JJ present) (NN liber)) (NP (NP (CD one) (NNP dachau)) (NNP concentr) (NN camp) (NN sub) (NN camp)) (PP (IN after) (S (NP (NN war)) (VP (VB settl) (NP (NML (NN salt) (NN lake)) (NNP citi) (NNP utah))))))))
# (ROOT (NP (NML (NNP tom) (NNP akashi) (FW nisei)) (NML (ADJP (FW male) (VBN born)) (NNP june) (FW merc)) (ADJP (ADJP (FW california) (FW grew)) (FW mount) (FW eden)) (NML (ADJP (FW california) (FW remov) (FW tanforan)) (FW assembl) (FW center) (FW california) (FW bomb) (FW pearl) (FW harbor) (FW incarcer) (FW topaz) (FW concentr) (FW camp) (FW utah) (FW move) (NML (FW tule) (NNP lake)) (FW concentr) (FW camp) (FW famili) (FW volunt) (NN move) (NP (NNP japan)) (SBAR (IN while) (ADJP (NP (FW tule) (FW lake)) (VP (FW join) (NP (ADJP (FW pro) (NNP japan)) (NML (NML (NML (NML (FW organ) (FW creat)) (FW father)) (FW sokoku)) (FW kenkyu) (FW seinen) (FW dan) (NNP young) (FW men) (FW associ) (FW studi) (FW motherland) (FW renounc) (NNP u) (POS s) (NN citizenship) (NNP expatri) (S (NP (NNP japan) (NN parent) (NNP sibl) (NML (NNP live) (NNP work)) (NML (NML (NNP japan) (NN return)) (NN unit)) (NN state) (NN author)) (VP (VBP betray) (S (VP (VB trust) (NP (NP (DT the) (NML (NN stori) (NN deport)) (NNP issei)) (UH hi) (NML (ADJP (JJ american) (VBN born)) (FW famili) (FW dure) (FW wwii) (FW publish)))))))))))))))
# (ROOT (S (NP (NP (NNP ma) (NNP akiyama) (NNP nisei) (NN male)) (VBN born)) (VP (MD may) (NP (NP (NNP eastport) (NNP idaho)) (VP (VBN spent) (NP (NN childhood) (NN spokan) (NN washington)) (PP (IN in) (NP (NP (NML (NN travel) (NNP japan)) (NN famili) (NN father)) (ADJP (ADJP (RB becam) (JJ ill)) (VB die)))))) (VP (VB attend) (S (NP (NN school) (NNP japan) (NML (NML (CD three) (NN year)) (NN return)) (NML (NML (NML (NN spokan) (NN work)) (NN farm) (NN follow)) (NML (NN bomb) (NN pearl) (NN harbor)) (NN volunt) (NN militari) (NN servic) (NN fail) (NN medic) (NN examin) (NN dure)) (NN war)) (VP (VBD took) (NP (NML (JJ brief) (NN trip)) (NML (NN manzanar) (NN concentr) (NN camp)) (NML (NML (NNP california) (NN camp)) (NN arkansa)) (NNP minidoka) (NML (NN concentr) (NN camp)) (NP (NNP idaho))) (PP (IN after) (NP (NN war) (NN work) (NN painter) (JJ larg) (NN sign) (NN spokan)))))))))
# (ROOT (NML (NN sab) (NNP akiyama) (NNP nisei) (JJ male) (VBN born) (NNP april) (NML (NN oak) (NNP grove)) (S (ADJP (NNP oregon)) (VP (VBD grew) (SBAR (S (NP (NML (NN hood) (NN river)) (NML (NNP oregon) (NN area)) (NN parent)) (VP (VBD ran) (S (NML (NML (NN farm) (NNP dure)) (NN world) (NN war)) (ADJP (NNP ii) (VP (VBN remov) (NP (NML (NN pinedal) (NN assembl) (NN center)) (NNP california) (NN tule) (NN lake) (NML (NML (NN concentr) (NN camp)) (NML (NNP california) (NNP minidoka)) (NN concentr) (NN camp) (NNP idaho) (NN volunt)) (NN serv) (NNP u) (POS s) (FW armi) (NN war)) (PP (IN after) (NP (NN militari) (NML (NML (NN servic) (NN return)) (NN hood)) (NN river) (NN area)))))))))))))
# (ROOT (S (NP (NML (FW sumi) (FW suguro) (FW akizuki)) (FW nisei) (FW femal) (FW born) (NML (FW januari) (NNP bellevu)) (NNP washington)) (VP (VBD grew) (NP (NP (ADJP (NNP bellevu) (FW remov)) (NML (NNP pinedal) (NN assembl) (NN center)) (FW tule) (NN lake)) (NML (NNP concentr) (NN camp))) (NP (NNP california) (NN world) (NN war)) (NNP ii) (PP (IN after) (S (NP (NN leav) (NN camp)) (VP (NN return) (X (NN bellevu))))))))
# (ROOT (S (NP (NML (NNP harri) (NNP akun)) (NNP nisei) (NN male) (VBN born)) (VP (MD may) (VP (NNP dure) (NP (NN world) (NN war)) (FW ii) (NN serv) (VP (VB interpret) (NP (NN militari) (NN intellig) (NN servic)))))))
# (ROOT (NP (NNP kenjiro) (FW akun) (FW nisei) (ADJP (FW male) (FW born)) (FW juli) (FW dure) (FW world) (FW war) (FW ii) (FW serv) (FW militari) (FW intellig) (FW servic)))
# (ROOT (S (NP (NNP gene) (FW akutsu) (FW nisei) (NML (NML (FW male) (VBN born)) (FW septemb)) (FW seattl) (NP (NNP washington))) (VP (VBD spent) (S (NP (NP (NML (FW prewar) (NN childhood)) (FW seattl) (FW nihonmachi) (FW incarcer)) (NML (NML (NML (NNP puyallup) (FW assembl) (FW center)) (NNP washington) (NNP minidoka)) (NNP concentr) (NN camp) (NNP idaho) (FW refus) (NN particip) (NN draft) (NN imprison)) (NML (NML (NNP mcneil) (NN island)) (NNP penitentiari)) (NNP washington) (NN draft)) (VP (VB resist) (NP (NN resettl) (NN seattl)))))))
# (ROOT (S (NP (NML (NNP jim) (FW akutsu)) (FW nisei) (FW male) (FW born) (NML (FW januari) (FW seattl)) (FW washington) (FW incarcer) (FW puyallup) (FW assembl) (FW center) (FW washington) (FW minidoka) (FW concentr) (FW camp) (FW idaho)) (VP (FW resist) (NP (FW draft) (FW rational) (FW u) (FW s) (FW govern) (FW classifi) (FW c) (FW enemi) (FW alien) (FW therefor) (NP (ADJP (FW oblig) (FW serv) (FW imprison)) (NML (NML (NNP mcneil) (NNP island)) (FW penitentiari)) (NNP washington) (JJ vocal) (NN critic) (NP (ADJP (NNP japanes) (JJ american) (NN citizen)) (NN leagu)) (NNP resettl) (NNP seattl) (NNP washington) (VBN thought) (NN model) (JJ main) (NN charact) (NNP john) (FW okada) (ADVP (UH no) (DT no) (NN boy)))))))
# (ROOT (S (NP (NP (NNP dorothi) (NNP almojuela) (NNP femal) (NNP suquamish) (JJ filipino) (NN descent)) (VP (VBN born) (S (NP (NNP januari))))) (VP (VBD grew) (S (NP (NP (NNP squamish) (NNP reserv)) (PP (IN near) (NP (NNP vancouv) (JJ british) (NNP columbia) (NNP canada)))) (VP (NN move) (NP (NP (NN bainbridg) (NN island) (NN work)) (NN strawberri) (NN farm) (NN marri) (FW rais)) (ADVP (FW famili)))))))
# (ROOT (S (NP (NML (NNP alic) (NNP matsumoto) (NNP ando)) (NNP nisei) (NNP femal) (VBN born) (NML (NNP januari) (NNP portland)) (NNP oregon)) (VP (VBD grew) (NP (NNP portland) (NN parent))) (VP (VBD ran) (S (NP (NML (NN hotel) (NNP dure) (NN world)) (NN war)) (ADJP (NNP ii) (VBN remov) (NP (NML (NNP portland) (NN assembl) (NN center)) (NNP oregon) (NNP minidoka) (NN concentr) (NN camp) (NNP idaho)))) (PP (IN after) (S (NP (NN leav) (NN camp)) (VP (NN return) (NP (NN portland))))))))
# (ROOT (NP (NP (NML (JJ emeri) (NNP brook) (NNP andrew)) (JJ white) (JJ male) (VBN born) (NN novemb) (NNP seattl) (NNP washington) (NN son)) (VP (NN reverend) (ADVP (NNP emeri) (NNP andrew)) (NP (NP (NNP japanes) (NML (NML (NN baptist) (NN church)) (NN minist)) (NNP seattl) (NNP mani) (NN year)) (PP (IN after) (NP (NNP japanes) (JJ american) (NML (ADJP (NNP seattl) (NNP remov)) (NNP minidoka) (NNP concentr) (NN camp) (NNP idaho) (NNP emeri) (NN brook) (NN move) (NML (NN famili) (NN twin) (NN fall)) (NNP idaho) (NN minist) (NNP nikkei) (NN camp) (S (VP (NN visit) (NP (NNP japanes) (JJ american) (NN friend) (NNP minidoka)) (PP (IN throughout) (NP (NP (NN war) (NN year)) (PP (IN after) (NP (NP (NN world) (NN war) (CD ii)) (NN return) (NN seattl)))))) (VP (VB attend) (NP (NML (NNP bailey) (NNP gatzert)) (NNP elementari) (NN school)) (PP (IN in) (NP (JJ recent) (NN year))) (VP (NN return) (NP (NP (JJ former) (NN site)) (NNP minidoka) (NN concentr) (NN camp))))))))))))
# (ROOT (S (NP (NML (NNP margi) (NNP nahmia)) (ADJP (NN angel) (JJ white)) (NN femal) (VBN born) (NML (NNP june) (NN seattl)) (NNP washington)) (VP (VBD grew) (S (NP (NML (JJ central) (NN district)) (NN seattl) (NN mother)) (VP (VBD ran) (NP (NML (NML (NN board) (NN hous)) (NN discus) (NN reaction) (NN japanes)) (JJ american) (NML (NML (NN peer) (NN leav)) (NML (NN seattl) (NN world))) (NN war)) (ADVP (NNP ii)))))))
# (ROOT (S (NP (NML (NNP dan) (NNP aoki)) (NNP nisei)) (ADJP (NNP male) (VBN born)) (NML (NNP januari) (NNP kealakekua)) (NP (NP (NNP hawai) (NN father)) (FW congreg) (NN preacher) (NNP dure) (NN world) (NN war) (NNP ii) (FW serv) (IN th) (NP (NP (NN battalion) (NN europ)) (PP (IN in) (NP (NML (NML (NNP activ) (NNP hawai)) (JJ democrat) (NNP parti) (NN campaign)) (NN statehood)))))))
# (ROOT (S (NP (NNP nanci) (FW k) (FW araki) (FW sansei) (FW femal)) (VP (FW born) (FW octob) (FW san) (FW francisco) (FW california) (FW dure) (FW world) (FW war) (FW ii) (FW remov) (NP (FW granada) (FW amach) (FW concentr) (FW camp) (FW colorado) (FW famili) (FW briefli) (FW left) (FW camp) (FW utah) (FW voluntarili) (VP (FW enter) (NP (FW topaz) (FW concentr) (FW camp)) (FW utah) (FW mother) (FW pregnant) (FW after) (FW leav) (FW camp) (FW return) (NP (FW san) (FW francisco) (FW resum) (FW elementari) (FW school)))))))
# (ROOT (S (S (NP (NML (NNP sam) (NNP araki)) (NNP nisei) (ADJP (NNP male) (VBN born)) (FW juli) (NNP saratoga) (NNP california)) (VP (VBD grew) (NP (NML (NNP saratoga) (FW father) (FW work) (FW garden)) (FW larg) (FW estat)))) (PP (FW after) (NP (FW bomb) (FW pearl) (FW harbor) (FW father) (FW move) (FW famili) (FW inland) (FW reedley) (FW attempt) (FW avoid) (FW mass) (FW remov) (FW eventu) (FW remov) (FW poston) (FW concentr) (FW camp) (FW arizona) (FW after) (FW leav) (FW camp) (FW return) (NML (NML (NML (FW california) (FW graduat)) (FW stanford) (FW univers)) (FW master)) (FW mechan) (FW engin))) (VP (VBD went)) (VP (VB establish) (NP (FW prestig) (FW career) (FW aerospac) (FW industri) (FW becom) (FW presid) (FW lockhe) (FW martin) (FW missil) (FW space)))))
# (ROOT (S (S (NML (FW sakay) (FW aratani) (FW nisei) (FW femal) (FW born) (FW decemb) (FW lo) (FW angel) (FW california)) (VP (VBD grew) (NP (FW gardena) (FW parent)))) (VP (VBD ran) (NP (NN chicken) (NN farm)) (PP (IN after) (ADJP (NML (NML (NN bomb) (FW pearl)) (NN harbor) (NN move)) (FW temporarili) (FW live) (NNP famili) (NNP reedley) (FW california) (FW remov) (NP (NNP poston) (FW concentr) (NN camp) (NNP arizona)))) (SBAR (IN while) (S (S (VP (VB visit) (NP (NML (NML (NN differ) (NN camp)) (NNP sakay) (FW met) (FW futur) (FW husband)) (NML (NML (FW georg) (FW aratani)) (FW marri) (FW minneapoli)) (FW minnesota) (NML (FW georg) (FW serv)) (FW militari) (FW intellig) (FW servic)) (PP (IN after) (NP (NML (NML (NN leav) (NN camp)) (NNP sakay)) (NML (NML (NML (NNP georg) (NN return)) (NNP lo) (NN angel)) (NNP rais)) (NNP famili) (NNP sakay))))) (VP (VBD found) (NP (NN member) (NNP montebello) (NNP japanes) (NN woman) (NN club)) (ADVP (RB also)) (NP (CD one) (NML (NML (JJ first) (NN woman)) (NN serv) (NN board)) (NML (NN sumitomo) (NN bank)) (NN california))))))))
# (ROOT (S (NP (NP (NML (NNP terri) (FW aratani)) (FW nisei) (NML (NML (NNP male) (NNP dure)) (NNP world) (NNP war) (NNP ii) (NNP serv) (NNP i) (NNP compani) (NN part) (NNP nd) (NN regiment) (NN combat) (NN team)) (NNP japanes) (NML (JJ american) (NN fight) (NN unit))) (NP (NP (CD one) (ADJP (NNP highli) (NN decor)) (NN militari) (NN unit)) (NML (NP (NP (NNP u) (POS s)) (NNP histori) (NNP dure) (NN interview) (NN discus)) (NN experi)))) (VP (NN train) (NP (NN camp)) (NN shelbi) (S (NP (NP (NNP mississippi) (NN fight) (NN europ)) (NN battl) (NN battl)) (VP (VBN lost) (NP (NN battalion)))))))
# (ROOT (S (NP (NNP yoshiko) (NNP asakura) (NNP japanes) (NNP femal)) (VP (VBN born) (FW novemb) (NNP shizuoka) (FW japan)) (VP (VBP attend) (NP (NML (NN school) (NN world)) (NN war)) (ADVP (NNP ii)) (PP (IN after) (S (NP (NN war)) (VP (VB enter) (NP (NN nurs) (NN profess) (NN becam)) (S (VP (NN involv) (NP (NN number) (NML (JJ social) (NN polit)) (NN caus)) (PP (IN in) (NP (NML (NN marri) (NNP kibei)) (NNP nisei) (NN move) (NN unit) (NN state)))))))))))
# (ROOT (NML (NNP setsuko) (NNP izumi) (FW asano) (FW nisei) (ADJP (FW femal) (VBN born) (NNP march) (FW boyl) (NN height)) (NN neighborhood) (NML (FW lo) (NN angel)) (NNP california) (NNP dure) (NNP world) (NN war) (NNP ii) (NNP remov) (NP (NP (NNP santa) (FW anita)) (NML (NML (FW assembl) (NN center)) (NNP california)) (NNP rohwer) (FW concentr) (NN camp) (FW arkansa)) (SBAR (IN after) (S (NP (NML (NML (NML (NN leav) (NN camp)) (NN move)) (NN famili) (JJ new) (NN orlean)) (NNP louisiana)) (VP (VB remain) (S (NP (NML (JJ new) (NN orlean)) (NML (NML (CD thirteen) (NN year)) (NN finish)) (NN school)) (VP (VB establish) (S (NP (NN career) (NN microbiologist) (NN eventu)) (VP (NN return) (ADJP (JJ lo) (NN angel)))))))))))
# (ROOT (S (NP (NML (NNP georg) (NNP azumano)) (NNP nisei) (ADJP (JJ male) (VBN born)) (NNP june) (NNP portland) (NNP oregon)) (VP (VBD grew) (NP (NNP portland) (NN parent))) (VP (VBD ran) (NP (NP (NML (NN hotel) (NNP groceri) (FW busi)) (NNP wa)) (NN draft) (NP (NML (NP (FW armi) (JJ prior) (NN bomb)) (NN pearl) (NN harbor) (NN transfer)) (FW armi) (NNP reserv) (NNP dure) (NN world) (NN war) (NNP ii) (FW remov) (NP (NML (NNP portland) (NN assembl) (NN center)) (NNP oregon) (NNP minidoka) (NN concentr) (NN camp) (NNP idaho)) (PP (IN after) (S (NP (NN war)) (VP (NN return) (S (NP (NN portland)) (VP (VB establish) (NP (NN success) (NN travel) (NN agenc))))))))))))
# (ROOT (NP (NML (FW peggi) (FW nishimura) (FW bain)) (FW nisei) (FW femal) (FW born) (NNP march) (NNP vashon) (NNP island) (NNP washington) (FW rais) (NNP vashon) (NNP island) (FW de) (FW moin) (NNP washington) (FW remov) (NP (CD two) (NN child) (NNP pinedal) (NML (NN assembl) (NN center)) (NNP california)) (ADVP (JJR later)) (NN transfer) (NNP tule) (NNP lake) (NP (NML (NNP concentr) (NN camp)) (NNP california) (NNP minidoka) (NNP idaho) (NNP resettl) (NNP chicago) (FW illinoi) (S (NP (NML (JJ live) (NN work)) (NNP chicago) (NN eventu)) (VP (VB return) (NP (NN seattl) (NNP washington)))))))
# (ROOT (S (NP (NP (NML (NNP sarah) (NNP baker)) (NML (NML (NNP brent) (NNP seto) (NNP bill)) (NNP tashima) (NN interview) (NNP sarah) (NNP e) (NNP baker) (NNP baker)) (NML (CD four) (NN time)) (NN chapter)) (VP (NN presid) (NP (NP (CD two) (NN time) (NN nation) (NN jacl) (NN vice)) (VP (NN presid) (NP (JJ local) (NN activist) (NML (NML (NN commun) (NN organ)) (NN actor)) (NN dancer) (NN director) (NN balanc) (NN task) (NN work)) (NP (JJ full) (NN time)))))) (NML (JJ full) (NN time)) (NN undergradu) (NN graduat) (NN student) (NN baker) (NN organ) (NP (CD two) (ADJP (NNP commun) (JJ wide))) (VP (NN gather) (NP (NN support)) (NN api) (NN lgbtq) (NN youth) (NN famili) (NP (NNP galvan) (NNP seattl) (NNP jacl) (NNP oppos) (NML (NP (JJ muslim) (NN travel)) (NN ban)) (NN plan) (NNP pnwdc) (NN nation) (NN youth) (NN student) (NN council) (NN activ) (ADVP (RB much))))))
# (ROOT (S (NP (NP (NNP denni) (NNP bambauer) (ADJP (NP (JJ male) (NN japanes)) (JJ french)) (JJ irish) (NN descent)) (VP (VBN born) (NP (NP (ADJP (NN octob) (NN lo) (NN angel)) (NNP california)) (NP (DT a) (NN child) (JJ resid) (NN child) (NN home) (NN societi))) (S (VP (NN orphanag) (ADJP (NNP lo) (NN angel)) (S (ADJP (NNP dure) (NN world) (NN war) (NNP ii)) (VP (NN transfer) (NP (NN manzanar) (NML (NML (NML (NN concentr) (NN camp)) (NN child)) (NN villag)) (NN orphan) (NN wa)))))))) (VP (VB adopt) (NP (NML (NML (NN camp) (NN famili)) (NN bishop)) (NNP california) (NN eventu)) (NN becam) (NP (NN teacher)))))
# (ROOT (NML (NNP kathryn) (FW bannai) (FW elain) (FW kim) (FW bill) (FW tashima) (FW interview) (FW kathryn) (FW bannai) (FW kathryn) (FW bannai) (NML (FW lead) (FW counsel)) (FW gordon) (FW hirabayashi) (FW coram) (FW nobi) (FW case) (FW februari) (PP (IN among) (NP (FW critic) (FW work) (NN success) (NN defeat))) (PP (FW govern) (NN effort)) (S (VP (VB dismiss) (NP (NNP hirabayashi) (NN case))) (VP (VBN led) (NP (NN overturn) (S (NP (NNP hirabayashi) (NN convict)) (VP (VB resist) (NP (NN curfew) (FW exclus) (NN order) (FW promulg) (FW e) (FW o) (FW bannai) (FW seattl) (FW jacl) (FW presid) (FW pivot) (NN period) (FW chapter) (NP (NNP it) (NN period) (NN chapter) (NN expand) (NN work)) (PP (IN toward) (NP (NNP wwii) (FW japanes) (NNP american) (FW redress) (NN age) (NNP health) (FW issu) (FW issei) (FW nisei) (FW youth) (FW program) (FW bannai))) (ADVP (RB also)) (NP (NML (NNP forg) (FW partnership) (FW japanes)) (NNP canadian) (FW share) (NNP wwii) (FW experi) (FW injustic) (FW bannai) (JJ third) (FW woman) (FW chapter) (FW presid) (NP (CD one) (JJ earliest) (FW sansei) (FW chapter) (FW presid) (FW bannai) (FW board) (JJ first) (FW seattl) (FW jacl) (FW board) (JJ major) (FW sansei)) (ADVP (RB also)) (NP (JJ major) (FW femal) (NN membership)))))))))))
# (ROOT (S (S (NP (NML (NNP lorrain) (FW bannai)) (FW sansei) (FW femal) (VBN born) (NML (FW lo) (FW angel)) (FW california)) (VP (VBD grew) (S (NP (FW gardena) (FW california)) (VP (FW surround) (S (NP (NP (FW larg) (FW japanes)) (JJ american) (NML (NML (ADJP (FW commun) (FW influenc)) (NN father) (NN role)) (FW commun) (FW polit) (NN mother)) (FW emphasi) (FW educ)) (VP (VB attend) (NP (FW univers) (NNP california) (FW santa) (FW barbara)))))))) (FW becam) (NP (ADJP (FW increasingli) (FW awar)) (FW japanes)) (S (NP (JJ american) (FW histori) (FW issu) (NML (JJ ethnic) (NN ident)) (JJ racial) (NN inequ)) (VP (VB attend) (NP (NN univers)) (S (NML (NML (NNP san) (NN francisco)) (NN school) (NN law) (NN hone)) (VP (VB commit) (NP (NML (JJ polit) (JJ social) (NN activ)) (NML (NN onli) (NN year)) (NML (NML (NML (NN law) (NN school)) (NN join)) (NML (NML (NN team) (NN lawyer)) (NN work) (NN reopen))) (NML (NML (NML (NN suprem) (NN court)) (NN decis)) (NNP korematsu) (NN v) (NN unit) (NN state) (NN convict) (JJ violat) (NML (NN exclus) (NN order)) (NN world) (NN war) (NN ii) (NNP mr) (NNP korematsu) (NN case) (VP (VBD went) (NN way)) (S (NP (NML (NML (JJ suprem) (NN court)) (NN exclus)) (NN incarcer) (NN japanes) (JJ american) (VBN upheld) (S (NML (NN constitut) (NN base)) (VP (VB govern) (NP (NN argument) (NP (NN militari) (NN necess))) (PP (IN through) (NP (NP (NML (NML (NN petit) (NN writ)) (NN error)) (NN coram) (NNP nobi)) (VP (VB establish) (S (NP (NP (NN case) (NN premis) (NN error) (NN fact)) (VBN withheld) (NN judg) (NN defens) (NN prosecut) (JJ legal) (NN team)) (VP (VBP reopen) (NN case) (NN provid) (S (VP (NN evid) (NP (NML (JJ factual) (NN underpin)) (NML (NML (NN exclus) (NN order)) (NN fraudul) (NN success)) (NNP korematsu)))))))))))) (VP (NN convict) (S (VP (NN vacat) (ADVP (RB well) (NN hand)) (NP (JJ similar) (NN convict)))) (PP (IN in) (NP (NP (NP (NP (NP (NN interview) (NN m)) (NN bannai) (NN discus) (NN coram) (NNP nobi) (JJ legal) (NN team)) (NN support) (NN effort)) (PP (IN among) (NP (NP (NNS japanes)) (NP (JJ american) (NML (NN commun) (NN person)) (NN lesson))))) (VP (NN gain) (NP (NN part) (NN effort)))))))))))))))
# (ROOT (S (S (S (NP (NML (NNP paul) (NNP bannai)) (NNP nisei) (JJ male) (VBN born) (NNP juli) (NNP delta) (NNP colorado)) (VP (VBD grew) (NML (NML (NML (NML (JJ small) (PRP mine)) (NN farm)) (NN town)) (NNP colorado)))) (FW utah) (FW arizona) (FW famili) (FW move) (FW boyl) (FW height) (FW lo) (FW angel) (NNP california) (FW area)) (PP (IN after) (NP (NML (NML (NML (FW graduat) (JJ high)) (NN school)) (NN test)) (FW discrimin))) (S (VP (VB employ) (ADJP (NP (FW practic) (FW eventu) (FW succeed)) (NN obtain) (NML (NML (NN job) (NN bank)) (FW dure)) (NNP world) (FW war)))) (FW ii) (NP (ADJP (FW famili) (VBN held)) (FW manzanar) (FW concentr) (FW camp) (FW california) (FW mr) (FW bannai) (FW join) (FW nd) (FW regiment) (FW combat) (FW team) (FW later) (FW transfer) (NP (FW u) (POS s) (FW militari) (FW intellig) (FW servic) (NNP he)) (VP (FW serv) (NP (FW new) (FW guinea) (FW elsewher) (FW oversea) (FW interpret) (FW alli) (FW translat) (VP (FW interpret) (NP (FW servic) (FW ati) (FW interpret) (FW surrend) (FW japanes) (FW forc) (FW ceremoni) (FW indonesia) (FW marri) (FW eventu) (FW resettl) (NP (FW gardena) (FW california) (FW work) (FW floral) (FW industri)) (VP (FW found) (NP (NP (FW bannai) (FW realti) (FW insur) (FW compani)) (NP (NP (FW an) (ADJP (FW extrem) (FW activ)) (FW commun) (NNP civic) (FW volunt) (FW mr)) (FW bannai)))) (FW join) (S (NP (NP (NML (FW elk) (NN club)) (ADJP (RB well) (FW mani)) (JJ veteran) (NN organ)) (SBAR (S (NP (PRP he)) (VP (VBP elect) (NP (NNP gardena) (NML (NML (NNP citi) (NN council)) (NN elect)) (NML (NNP california) (NN state)) (NN legislatur)) (PP (IN in) (NP (NNP mr) (NP (NNP bannai) (FW becam) (NP (JJ execut) (NN director) (NN commiss) (NN wartim) (NN reloc) (NN intern) (JJ civilian) (NN cwric))))) (PP (IN in) (S (VP (VB appoint) (NP (JJ chief) (NN director) (NN memori) (NN affair))))))))) (VP (VB depart) (NP (NP (NN veteran) (NN administr)) (VP (NN presid) (NP (NNP ronald) (NNP reagan)))))))))))))
# (ROOT (S (NP (NML (NN yone) (NNP bartholomew) (NNP nisei) (NNP femal) (VBN born) (NNP april) (NNP bedderavia) (NNP california)) (VP (NNP wa) (VP (VBN given) (S (VP (VB adopt) (NP (NN parent) (NN coupl))))))) (VP (MD could) (NP (NN child))) (VP (VBD grew) (NP (NN famili) (NN farm)) (NP (NP (CD one) (JJS oldest) (NML (NNP nisei) (NNP santa) (NN barbara) (NN area)) (NML (NML (NML (NNP california) (NN incarcer)) (NNP puyallup)) (NN assembl) (NN center)) (NNP washington) (NN minidoka) (NN concentr) (NN camp) (NNP idaho) (NN widow) (NN clarenc) (NN arai) (NN lawyer) (JJ key) (NN figur)) (VP (VBN found) (NP (NP (NN japanes) (JJ american) (NN citizen) (NN leagu)) (PP (IN in) (NP (NP (NP (NML (NML (NN interview) (NN discus)) (NN childhood)) (NN memori)) (NN marri) (NN clarenc) (NML (JJ turbul) (NN war)) (NN year)) (PP (IN after) (S (NP (NN war)) (VP (NN support) (NP (NML (NML (NN famili) (NN care)) (NN ail)) (NN clarenc) (NN death) (NN remarri) (NNP georg) (FW bartholomew)))))))))))))
# (ROOT (NML (NNP gerald) (NNP l) (NNP beppu) (FW sansei) (NNP male) (NNP famili) (JJ own) (NML (NNP linc) (NNP tackl) (NNP longtim) (FW japanes) (JJ american)) (ADJP (NNP busi) (NNP seattl)) (NNP washington) (JJ prior) (NN world) (NN war) (S (NP (NNP ii) (NN father)) (VP (VBZ becam) (NP (NML (NP (NP (NP (NN owner) (NNP togo)) (NN tackl)) (NN shop)) (NN dure) (NN war) (NN remov)) (NML (NNP puyallup) (NN assembl) (NN center)) (NML (NNP washington) (NNP minidoka)) (NML (NN concentr) (NN camp)) (NN idaho)))) (SBAR (IN while) (S (NP (NP (NML (NN famili) (NN camp)) (JJ prewar) (NN insur) (NN agent)) (VP (VBN paid) (NN premium))) (VP (MD could) (VP (VB retain) (NP (NN insur) (NN polici)) (SBAR (IN after) (S (VP (NN return) (NP (NML (NN seattl) (NNP gerald) (NN father)) (NN abl) (NN use) (NN fund) (NN polici)) (S (VP (VB establish) (NP (NN linc)))))))))))))
# (ROOT (NP (FW june) (FW yasuno) (FW aochi) (FW yamashiro) (FW berk) (FW nisei) (FW femal) (FW born) (FW octob) (FW lo) (FW angel) (FW california) (FW grew) (FW lo) (FW angel) (FW involv) (FW earli) (FW age) (FW tradit) (FW japanes) (FW danc) (FW stage) (FW perform) (FW dure) (FW world) (FW war) (FW ii) (FW remov) (FW famili) (FW santa) (FW anita) (FW assembl) (FW center) (FW california) (FW rohwer) (FW concentr) (FW camp) (FW arkansa) (FW after) (NNP leav) (NNP camp) (FW famili) (FW resettl) (NNP denver) (NNP colorado) (CD ten) (NN year) (NN return) (NP (NNP california)) (PP (FW after) (NP (NML (NNP war) (FW pursu)) (NML (NN career) (NN model)) (NN actor) (NN time))) (VP (VBN got) (NP (FW involv) (FW numer) (FW japanes) (FW american) (FW commun) (FW group)))))
# (ROOT (S (NP (NML (NNP marion) (NNP michiko)) (NNP bernardo) (NNP nisei) (ADJP (NNP femal) (VBN born)) (NML (NML (NNP juli) (NNP walnut)) (NNP grove)) (NNP california)) (VP (VBD grew) (NP (NNP walnut) (NNP grove)) (SBAR (IN after) (S (NP (NP (NML (NP (NML (NN bomb) (NN pearl)) (NN harbor)) (NNP remov) (NN famili) (NN merc) (NN assembl) (NN center)) (NNP california) (NNP granada) (NNP amach) (NNP concentr) (NN camp)) (NNP colorado) (VBN left) (NN camp)) (VP (VB attend) (S (NP (NML (NN board) (NN school)) (JJ new) (NNP york) (NN eventu)) (VP (VB return) (NP (NML (NNP walnut) (NNP grove)) (NNP marion) (FW pas)) (ADVP (RB away)))))))) (FW decemb)))
# (ROOT (S (NP (NML (NNP angela) (NNP berri) (NNP femal) (JJ filipino) (JJ american) (NN descent)) (VP (VBN born) (NP (NN seattl) (NNP washington)))) (VP (VBD grew) (NP (NML (NN bainbridg) (NN island)) (NML (NML (NML (NNP washington) (NN granddaught)) (FW felix)) (NN nart)) (NML (NP (CD one) (ADJP (RB well) (VBN known)) (JJ filipino) (NNS men)) (VP (NN bainbridg) (NP (NN island) (NN work) (NN japanes)) (NP (JJ american) (NN strawberri) (NN farmer))))))))
# (ROOT (S (NP (NNP bob) (NNP berri) (JJ white) (NN male)) (VP (VBD grew) (NP (NNP pasadena) (NNP california) (NN parent) (NN flower) (NN grow) (NML (ADJP (NN busi) (JJ provid)) (NN flower) (NN santa) (NN anita)) (NML (NML (NN racetrack) (NN fifti) (NN year)) (NN dure)) (NN world) (NN war)) (VP (NNP ii) (VP (NN visit) (NP (NNP japanes)) (NP (NP (NP (JJ american) (NN friend)) (NML (NP (NNP santa) (NN anita)) (NN assembl) (NN center)) (NNP california) (NNP gila) (NN river) (NN concentr) (NN camp)) (NP (NNP arizona))))))))
# (ROOT (S (NP (ADJP (NNP ernest) (NNP besig) (JJ white) (NN male) (VBN born)) (VP (MD may) (ADVP (NNP albani)) (NP (NP (JJ new) (NNP york) (NN founder) (NN execut) (NN director) (NML (JJ american) (JJ civil)) (NNP liberti) (NN union)) (JJ northern) (NNP california)))) (VP (VBD fought) (NP (JJ civil) (NN right)) (PP (IN throughout) (NP (NN career) (NN involv) (NML (NML (NN gener) (NN strike)) (NNP san) (NN francisco) (NN mccarthi) (NN era)) (NML (JJ free) (NN speech)) (ADJP (JJ civil) (JJ right)) (JJ anti) (NN war) (NN movement)))) (VP (VBZ repres) (S (NP (NNP fred) (NML (NML (NNP korematsu) (NN case)) (NN unit)) (NN state)) (VP (VBZ govern))))))
# (ROOT (S (NP (FW theo) (NML (FW bickel) (FW elain)) (FW kim) (FW joy) (FW misako)) (FW st) (FW germain) (FW interview) (FW theo) (FW bickel) (FW theo) (FW introduct) (NP (NML (FW jacl) (FW intern) (FW nation)) (FW jacl)) (PP (FW at) (NP (NML (FW jacl) (FW nation)) (FW convent) (FW la) (FW vega) (FW bill) (FW tashima) (FW invit) (NP (FW theo) (FW work) (FW collabor) (FW seattl) (FW jacl) (FW chapter) (FW theo) (FW focu) (FW strengthen) (NP (FW commun)) (PP (IN among) (NP (NML (FW jacl) (FW member)) (FW execut) (FW jacl) (FW leadership) (FW encourag) (NML (FW commun) (FW engag)) (FW work) (ADJP (NML (JJ civil) (JJ right)) (JJ social)) (NNP justic) (S (ADVP (FW theo)) (VP (VB reflect) (NP (CD one) (NN meaning) (NN event)) (S (VP (NN help) (VP (NN coordin) (PP (IN alongsid) (NML (NML (NNP puyallup) (NN valley)) (FW jacl) (FW chapter) (FW th) (FW anniversari) (NNP puyallup) (FW assembl) (FW center) (FW camp) (FW harmoni) (NN event) (NN reconnect) (VP (VB differ) (NP (NP (FW gener) (FW japanes)) (JJ american) (NN site) (FW camp) (FW harmoni) (FW mani) (FW individu) (FW share) (FW stori) (FW help) (S (VP (FW heal) (NP (NN trauma)) (S (ADJP (FW incarcer) (VB creat))) (PP (IN within) (NP (NN fairground) (FW wwii) (S (ADVP (FW theo)) (VP (VB share) (NP (NML (NN thought) (NN import)) (NML (NML (NNP jacl) (NN activ)) (NN fight)) (S (ADJP (JJ justic) (NNP erad) (NN hate) (VP (NN creat) (VP (NN prejudic)))))))))) (S (NP (DT the) (NN seattl) (NN jacl) (NN chapter) (VP (NN serv) (NP (JJ strong) (NN platform)))) (VP (VB make) (S (NP (NN genuin) (VB connect)) (NP (NN authent) (NN individu)) (S (VP (VB commit) (VP (VB enact) (NP (NML (JJ social) (NN chang)) (NN japanes)) (NP (JJ american) (NNP bipoc) (NNP immigr) (FW commun)))))) (SBAR (IN while) (S (S (NP (ADJP (NN mani) (JJ dear)) (NML (NN jacl) (NN friend)) (NN colleagu) (FW pas) (NNP theo) (JJ express) (NN confid) (NN futur) (NN chapter)) (VP (VB transform) (NP (NN way)))) (VP (MD can) (RB not) (VP (VB compar) (NP (NN past))))))))))))))))))))))))))
# (ROOT (S (NP (NML (NNP kazuko) (NNP uno) (NNP bill)) (NNP nisei) (ADJP (NNP femal) (VBN born)) (NML (NNP june) (NNP seattl)) (NML (NML (NNP washington) (FW rais)) (NNP south) (NNP park)) (NML (NML (NML (NNP washington) (NN famili)) (NN oper)) (NML (JJ small) (NN produc))) (NN farm)) (VP (VBP attend) (NP (NP (NP (NML (NNP cleveland) (NML (JJ high) (NN school)) (NN univers)) (NNP washington)) (NNP wa) (NP (JJ senior) (NN year)) (NML (NML (NML (JJ colleg) (NN decemb)) (NN father)) (NN pick) (NML (NNP fbi) (NN follow) (NN bomb))) (NN pearl) (NN harbor)) (VP (VBN sent) (S (NP (NNP missoula) (NML (NML (NN intern) (NN camp)) (NN montana)) (NML (NML (NML (NN famili) (NN remov)) (NML (NN pinedal) (NN assembl) (NN center))) (NN tule) (NN lake)) (NML (NML (NML (NML (NN concentr) (NN camp)) (NML (NML (NNP california) (NN work) (NN lab)) (NN technician)) (NN tule) (NN lake)) (NN hospit)) (NML (VBN left) (NN camp)))) (VP (VB attend) (SBAR (S (NP (NML (NN woman) (NN medic) (NN colleg)) (NNP philadelphia) (NNP pennsylvania)) (VP (VBD did) (NP (NML (JJ resid) (NN tuberculosi) (NN hospit)) (NNP detroit) (NNP michigan) (JJ special) (NN radiolog) (NN practic) (NML (NML (NNP michigan) (NN tennesse)) (NNP washington)) (NNP california) (NN retir))))))))))))
# (ROOT (S (NP (NNP mabel) (NNP shoji) (NNP bogg) (NNP nisei) (FW femal)) (VP (VBN born) (S (NP (NNP august) (NNP portland) (NNP oregon)) (VP (VBN lost) (NP (NP (NP (NN father)) (JJ earli) (NN age) (NN mother)) (NNP sibl) (NN set) (NP (NN famili) (NN farm)) (JJ greenhous) (NN busi) (NNP dure) (NN world) (NN war) (ADVP (NNP ii)) (VP (VBN remov) (NP (NML (NNP portland) (NN assembl) (NN center)) (NNP oregon) (NNP minidoka) (NN concentr) (NN camp) (NNP idaho)) (PP (IN after) (S (NP (NN leav) (NN camp)) (VP (NN return) (NP (NNP oregon))))))))))))
# (ROOT (S (S (NP (NNP david) (NNP r) (ADJP (NNP boyd) (JJ white)) (ADJP (JJ male) (VBN born)) (NML (NNP februari) (NNP seattl)) (SBAR (S (NML (NNP washington)) (VP (VBD grew) (NP (NML (NML (NN seattl) (NN father)) (NN gene)) (NNP boyd) (NN work) (NN seattl) (NN park)))))) (VP (NN depart) (NN gene))) (NP (NML (NML (NNP boyd) (NN athlet)) (NN director) (NN collin) (NN field)) (NN hous)) (NP (NML (NML (JJ close) (NN relationship)) (NN member)) (VP (NN japanes) (NP (JJ american) (FW commun) (FW seattl) (FW notabl) (NN world) (NN war) (NNP ii) (NN gene) (NNP boyd)))) (VP (NNP do) (NP (FW nat) (NN athlet)) (S (VP (VB equip) (NP (NP (NN japanes)) (JJ american) (NN youth))))) (VP (VBD held) (NP (NML (NNP puyallup) (NN assembl) (NN center)) (NNP washington)))))
# (ROOT (S (NP (NP (NML (NNP robert) (NNP bob)) (NNP bratt)) (VBN born) (NML (NNP bethesda) (NNP maryland)) (NML (NML (NNP dure) (NN redress)) (NN movement)) (NN work)) (VP (VB depart) (NP (NML (JJ justic) (NN offic) (NN redress)) (NN administr)) (S (ADVP (NNP os)) (VP (VB establish) (NP (NN identifi) (NN administ) (NML (NN repar) (NN payment)) (NN elig) (NN individu)) (PP (IN from) (NP (NN administr) (NML (NN offic) (NN redress)) (NN administr))) (ADVP (RB well)) (VP (VB execut) (NP (JJ offic) (NML (JJ civil) (JJ right)) (NN crimin) (NN divis)) (SBAR (IN after) (S (NP (NN retir)) (VP (VB depart) (NP (NP (JJ justic) (NN work) (NN privat) (NN sector) (NN saic)) (FW unisi) (FW dla) (FW piper) (FW llp)))))))))))
# (ROOT (NP (NP (NN bill) (ADJP (NNP bray) (JJ male) (JJ spanish)) (JJ irish) (NN descent)) (VP (VBN born) (NP (NP (NN march)) (NNP santa) (NNP monica) (NML (NNP california) (NN move)) (NNP salina) (NNP california) (NN teenag) (NN enlist) (NML (NN militari) (NN station)) (NML (NML (NN philippin) (NN japanes)) (NN bomb)) (NN pearl) (NN harbor) (NN captur) (NN japanes) (NN militari) (NN forc) (NN infam) (S (NP (NNP bataan) (NN death) (NN march)) (VP (VBN held) (NP (NP (NP (NN prison) (NN war) (NN releas)) (NN return)) (NN unit) (NN state))))))))
# (ROOT (S (NP (NML (NNP nikki) (FW bridg)) (FW nisei) (FW femal) (FW born) (FW februari)) (VP (VBD grew) (NP (NP (NML (NNP california) (FW dure) (NNP world) (FW war) (FW ii) (FW remov)) (NNP poston) (NNP colorado) (FW river) (NNP concentr) (NNP camp)) (NP (NNP arizona))) (PP (FW after) (NP (NNP leav) (NNP camp) (FW work) (FW war) (FW reloc) (FW author) (NNP offic) (FW san) (FW francisco))))))
# (ROOT (S (ADJP (NP (NNP harold) (NNP hal) (NNP champ)) (JJ white) (JJ male) (VBN born)) (VP (VBD grew) (S (NP (NML (NNP bainbridg) (NNP island)) (NNP washington)) (VP (NN join) (NP (NP (NML (NNP navi) (NN world) (NN war)) (NNP ii) (FW eventu)) (NN return) (FW bainbridg)))))))
# (ROOT (NML (NNP con) (NNP ni) (NNP thorson) (NNP chandler) (JJ white) (NNP femal) (VBN born) (NNP denver) (NNP colorado) (NN father) (NN work) (NN bureau) (NML (NNP reclam) (NN time)) (S (ADJP (NNP wwii)) (VP (VBD broke) (NP (NML (NML (NML (NNP famili) (JJ live) (NNP minidoka) (NNP concentr) (NN camp) (NNP idaho)) (NNP mr) (NML (NNP chandler) (NN child)) (NN time)) (NN attend)) (NML (NML (NML (NML (NNP elementari) (NN school)) (NNP minidoka)) (NN move)) (NNP twin) (NN fall)) (JJ junior) (JJ high) (JJ high) (NN school) (NN year)) (VP (NN attend) (S (NP (NNP univers) (NNP washington) (NML (NML (NNP live) (NNP lopez)) (NNP island)) (NNP washington)) (VP (VB spend) (NP (NN part) (NN year) (JJ small) (FW commun) (FW hondura)))))))))
# (ROOT (S (NP (NML (NNP joann) (NNP chiedi) (VBN born)) (NML (NNP washington) (NNP d) (FW c)) (NML (NML (NNP dure) (NN redress)) (NN movement)) (NN work)) (VP (VBP depart) (NP (NP (JJ justic) (NN offic) (NN redress) (NN administr)) (ADVP (NNP os))) (S (VP (VB establish) (NML (NML (NN identifi) (NN administ)) (NML (NML (NN repar) (NN payment)) (NN elig)) (NN individu) (NN work) (NN os) (NN deputi) (NN director) (NN verif) (NN unit)) (SBAR (IN after) (S (NP (NN leav) (NN os)) (VP (VBD went) (NP (NN work) (NN deputi) (NN execut) (NN offic)) (VP (VB depart) (NP (JJ justic) (NML (NML (JJ civil) (NN right)) (NN divis)) (NN deputi) (NN director) (ADJP (NN manag) (S (VP (NN depart) (NP (NML (NP (NN health) (JJ human)) (NN servic)) (NN offic))))) (NML (NML (NML (JJ civil) (JJ right)) (NN act)) (NN inspector) (NN gener)) (NML (NML (NN offic) (NN inspector)) (NN gener)) (NML (NML (NN chief) (NN administr)) (NML (NN offic) (NN dla)) (NN piper) (FW llp))))))))))))
# (ROOT (NP (NML (FW michiko) (FW franc)) (FW chikahisa) (FW nisei) (FW femal) (FW born) (FW januari) (FW lo) (FW angel) (FW california) (FW grew) (FW lo) (FW angel) (FW father) (VBD ran) (ADJP (FW success) (FW produc) (FW busi) (FW dure) (FW world) (FW war)) (FW ii) (S (VP (FW remov) (NP (NP (FW santa) (FW anita)) (NML (NML (FW assembl) (FW center)) (FW california)) (NML (NML (FW rohwer) (FW concentr)) (FW camp)) (FW arkansa)) (PP (IN after) (S (NP (NP (NN leav) (NN camp)) (NN return) (NP (NN lo) (NN angel)))))) (VP (VB attend) (S (NP (NN colleg) (NN eventu)) (VP (VB earn) (NP (NML (NN master) (NN degre)) (NML (NML (JJ social) (NN work)) (NN practic)) (NML (NML (JJ social) (NN work)) (NN lo) (NML (NN angel) (NNP eventu)) (NNP chicago) (FW illinoi)))))))))
# (ROOT (SINV (NP (NNP ben) (FW chikaraishi) (FW nisei) (FW male) (FW born) (FW septemb) (FW colusa) (FW california) (NP (FW a) (FW child) (FW famili) (FW move)) (S (NP (NNP stockton) (NNP california) (FW parent) (JJ own) (NN hotel) (NNP wa)))) (VP (VBD attend)) (NP (NP (NNP univers)) (NP (NP (NNP california) (NNP berkeley)) (NML (NML (NNP japan) (FW bomb)) (FW pearl) (FW harbor) (FW famili) (VBN sent)) (NML (NML (NNP rohwer) (FW concentr) (FW camp)) (ADJP (FW arkansa) (VBN left)) (NN camp)))) (NP (NP (JJ live) (NNP chicago) (FW illinoi)) (FW becam) (NN optometrist))))
# (ROOT (S (NP (NP (NML (NML (NNP ryan) (NN chin)) (NNP camila)) (NML (NML (NML (NML (NNP nakashima) (NNP bill)) (NNP tashima)) (NN interview)) (NNP ryan) (NNP chin) (NNP ryan) (NN chin) (FW seattl)) (FW jacl) (NN chapter)) (VP (VBN presid) (ADVP (RB also)))) (NP (NML (CD three) (NN time)) (NN nation) (NN jacl) (NN vice) (NN presid) (NN chin) (NNP becam) (FW activ) (NNP seattl) (NNP jacl) (NN student) (NP (NNP uw) (NN organ) (NN success) (NN event)) (S (NP (DT a) (JJ presid) (NN chin)) (VP (VB transform) (VP (VB bring) (NP (NP (NN chapter)) (NML (NML (NN age) (NN technolog)) (NN work)) (NN tirelessli) (NN improv) (NN chapter)) (NML (NN infrastructur) (NN area)) (NN board) (NN respons) (JJ fiscal) (NN oversight)))))))
# (ROOT (S (NP (NNP helen) (FW harano) (FW christ) (FW sansei) (FW femal) (FW born) (FW august) (FW berkeley) (FW california)) (VP (FW remov) (NP (FW tanforan) (FW assembl) (FW center) (FW california) (FW topaz) (FW concentr) (FW camp) (FW utah) (NP (NML (NML (FW famili) (FW resettl) (FW north) (NNP platt)) (NNP nebraska) (NN father)) (FW oper) (NN flower) (NN shop)))) (VP (VBD receiv) (S (NML (NML (NNP undergradu) (FW degre)) (FW educ) (FW sociolog) (FW hast) (NNP colleg) (NNP nebraska)) (VP (VB attend) (NP (NML (NNP mccormick) (NNP seminari) (FW illinoi) (FW marri) (NN husband)) (NML (NML (JJ frank) (NN christ)) (NN work) (NN teacher)) (NML (NN school) (NN desegreg)) (NN effort)))))))
# (ROOT (S (NP (NML (FW diana) (FW morita) (FW cole)) (FW nisei) (ADJP (FW femal) (VBN born))) (VP (MD may) (NML (NML (NML (NNP minidoka) (NNP concentr)) (NN camp)) (NNP idaho)) (NML (JJ prior) (NN world) (NN war)) (NNP ii) (NN parent) (NML (NML (JJ live) (NN hood)) (NN river)) (NP (NNP oregon)) (SBAR (IN after) (S (NP (NML (NN bomb) (NN pearl)) (NN harbor)) (VP (VBZ remov) (NP (NML (NN pinedal) (NN assembl) (NN center)) (NNP california) (NML (NML (NML (NN tule) (NN lake)) (NN concentr) (NN camp)) (NML (NNP california) (NN transfer)) (NN minidoka))) (SBAR (IN after) (S (NP (NML (NML (NN leav) (NN camp)) (NN famili) (NN resettl)) (NNP chicago) (NN parent)) (VP (VBD took) (S (NP (NP (NN job) (NML (NN factori) (NN dure)) (NN vietnam) (NN war) (NN move)) (NML (NNP canada) (NN husband)) (NML (NML (NML (NML (JJ civil) (JJ right)) (NN movement)) (NN activist)) (NN act))) (VP (NN resist) (NP (NP (NN award) (NN win)) (NN author) (NN book) (NN sideway) (NN memoir) (NN misfit)))))))))))))
# ...
# (ROOT (S (S (NP (NML (NNP marian) (NNP shingu) (NNP sata)) (NNP nisei) (ADJP (NNP femal) (VBN born)) (NNP august) (NNP lo) (NN angel) (NP (NNP california))) (VP (VBD grew) (NP (NML (NNP gardena) (NN father)) (FW promin) (NML (FW commun) (NN leader)) (NNP princip) (FW japanes)))) (FW languag) (NN school) (NNP dure) (NN world) (NN war) (NNP ii) (VBN remov) (NP (NN famili) (NML (NNP stockton) (NN assembl) (NN center)) (NNP california) (NNP rohwer) (NN concentr) (NN camp) (NN arkansa) (NP (VBN left) (NN camp))) (PP (IN along) (NP (NP (NN group) (NNS japanes)) (JJ american) (NN famili))) (VP (VBP establish) (SBAR (S (NP (NN farm) (NN arkansa)) (VP (VBP attend) (S (NML (NML (JJ littl) (NN rock) (JJ high)) (NN school)) (VP (NN return) (NP (NN famili) (NNP pasadena) (NNP california)) (PP (IN after) (NP (NN world) (NN war))) (PP (NNP ii) (NNP involv) (NP (NNP japanes) (JJ american) (NNP commun) (NNP pasadena)))))))))))
# (ROOT (S (S (NP (NML (FW dorothi) (FW h) (FW sato) (FW nisei)) (FW femal) (NML (FW born))) (VP (MD may) (NP (NNP carlisl) (NNP washington)))) (VP (VBD grew) (NP (NNP seattl) (NNP washington) (NN parent))) (VP (VBD ran)) (S (NP (NML (NML (NN hotel) (NNP dure)) (NN world)) (NN war)) (ADJP (NNP ii)) (VP (VBD remov) (NP (NML (NML (NNP puyallup) (NN assembl) (NN center)) (NNP washington) (NNP minidoka)) (NNP concentr) (NN camp) (NP (NNP idaho))) (PP (IN after) (NP (NP (NN leav) (NN camp)) (NML (NML (JJ live) (NN time)) (NNP chicago) (NN illinoi) (NN return)) (NNP oregon)))))))
# (ROOT (S (NP (NML (JJ frank) (NNP sato) (NNP nisei)) (ADJP (JJ male) (VBN born)) (NNP march) (NNP puyallup) (NNP washington)) (VP (VBD grew) (NML (NML (NML (NNP sumner) (NNP washington) (NN area)) (NN parent) (NN produc)) (NN busi) (NNP dure) (NN world) (NN war)) (S (NNP ii) (VP (VBN remov) (NP (NML (NNP famili) (NNP puyallup)) (NML (NN assembl) (NN center)) (NNP washington) (NNP minidoka) (NN concentr) (NN camp) (NNP idaho)) (SBAR (IN after) (S (NP (NN war)) (VP (VB attend) (S (NP (NP (NN univers) (NNP washington) (NN univers)) (SBAR (S (NP (JJ southern) (NNP california)) (VP (VBP establish) (NP (NN career) (VBP govern)) (PP (IN from) (S (VP (VP (NN work) (NP (NP (NN u) (POS s)) (NML (NML (NML (NN air) (NN forc)) (NN auditor)) (NN gener)) (NN offic)) (PP (IN from) (NP (NN offic)))) (NN assist) (NP (NN secretari) (NN defens) (NN comptrol)) (PP (IN from) (NP (NML (NN deputi) (NN assist)) (NML (NML (NML (NML (NN secretari) (NN defens)) (NN audit)) (NN becam)) (NN inspector)) (NN gener)))))))))) (VP (VBP depart) (S (NP (NML (NML (NN transport) (NN appoint)) (NN inspector) (NN gener)) (NN environment)) (VP (VB protect) (NP (NN agenc) (NN presid) (NNP ronald) (NNP reagan)) (SBAR (IN after) (S (VP (VB govern) (NP (NP (NN career) (NNP frank) (NN serv) (NN presid) (NN japanes)) (NML (NML (NML (NML (JJ american) (NN citizen)) (NN leagu) (NN work)) (NN activist)) (NN redress)) (NN movement)))))))))))))))))
# (ROOT (S (NP (NP (NML (NNP lillian) (NNP sato)) (NNP nisei) (NNP sansei) (NNP femal) (VBN born) (NNP decemb) (NML (NML (NML (NNP stockton) (NNP california)) (NN father) (NNP issei)) (NN mother)) (NNP nisei)) (VP (VBN born) (S (NP (NNP hawaii))))) (VP (VBD grew) (NP (NP (NP (NML (NNP santa) (NNP monica)) (NNP california) (NML (NNP dure) (NNP world)) (NN war) (NNP ii) (NN move)) (SBAR (S (NP (NNP famili) (NNP colorado)) (VP (VBP avoid) (NP (NN mass) (NN remov)))))) (VP (VB remain) (NP (NNP denver)) (ADVP (RBR later)) (NP (NP (NN oper) (NN groceri) (NN store)) (JJ greenhous) (NN busi) (NN husband)))))))
# (ROOT (S (NP (NML (FW luri) (FW sato) (FW nisei)) (FW femal) (FW born) (NML (FW januari) (FW montavilla)) (NNP oregon)) (VP (VBD grew) (ADJP (NNP portland)) (S (VP (FW attend) (NP (NML (NML (JJ colleg) (NN world)) (NN war)) (NNP ii) (NNP dure) (NP (NN war)) (VP (VBN remov) (NP (NML (NNP portland) (NN assembl) (NN center)) (NNP oregon) (NML (NML (NNP minidoka) (NN concentr) (NN camp)) (NNP idaho))) (NP (NP (NML (VBN left) (NN camp)) (NN husband)) (NML (ADJP (JJ live) (JJ new)) (NNP york) (NNP washington) (NNP d) (NNP c)) (NN eventu) (NN return) (NNP portland)))))))))
# (ROOT (S (NP (NML (NNP maria) (NNP sato)) (NNP nisei) (NML (ADJP (NNP femal) (VBN born)) (NNP novemb) (NNP trujillo)) (NNP peru) (NN father)) (VP (VBD ran) (S (VP (VB construct) (NP (NN compani)) (SBAR (IN after) (S (NP (NP (NML (NN bomb) (NN pearl) (NN harbor)) (NN father) (NN arrest) (NNP fbi)) (VP (VBN taken) (NN unit) (NN state) (S (NP (DT the) (NN famili)) (VP (VB join) (NP (NML (NN crystal) (NN citi)) (NN texa)))))) (VP (VBD went) (NP (NML (NNP japan) (NN war)) (NNP maria) (NML (JJ live) (NN work)) (NML (NML (NNP japan) (NN move)) (NN unit)) (NN state))))))))))
# (ROOT (NP (NML (NNP rick) (FW sato)) (FW nisei) (NML (NML (FW male) (FW born)) (NNP april)) (NML (NML (FW wapato) (FW washington)) (FW famili) (FW farm) (FW yakima) (FW valley)) (FW washington) (FW war) (FW incarcer) (FW portland) (NML (FW assembl) (FW center)) (FW oregon) (NML (FW heart) (FW mountain)) (FW concentr) (FW camp) (FW wyom) (FW serv) (FW briefli) (NP (FW militari)) (FW intellig) (NNP servic) (FW mi) (FW resettl) (NNP wapato) (NNP washington)))
# (ROOT (S (NP (NP (NML (NNP sarah) (NNP sato)) (FW sansei) (FW femal) (NN mother) (NN father)) (VP (VBN born) (NP (ADJP (NNP hawaii) (VBN born)) (FW februari) (FW peru)))) (VP (VBD spent) (S (NP (ADJP (JJ prewar) (NN childhood)) (NNP peru) (NNP hawaii) (NN father)) (VP (NN pick) (NP (NNP fbi) (NN detain) (NML (NML (NN bomb) (NN pearl)) (NN harbor)) (ADJP (NNP wa) (FW incarcer)) (FW jerom) (FW concentr) (NN camp) (NN arkansa) (FW tule) (NN lake) (S (NP (NML (NN concentr) (NN camp)) (NP (NNP california) (NN renounc) (NP (NN citizenship) (NN order)) (NN stay)) (NN parent) (NN expatri) (NNP japan)) (VP (VB regain) (NP (NNP u) (POS s) (NML (NML (NN citizenship) (NN return)) (NN unit)) (NN state))))))))))
# (ROOT (S (S (NML (JJ tad) (NN sato) (NNP nisei) (NN male) (VBN born)) (VP (MD may) (NP (NP (NNP portland) (NNP oregon) (VB move) (NML (NML (NN seattl) (NN father)) (NN parent)) (NN divorc)) (VP (VBD grew) (SBAR (S (NP (NN seattl) (NNP nihonmachi) (NN father)) (VP (VBD ran) (NP (NP (NML (JJ secondhand) (NN store)) (NN disinterest) (NN colleg)) (VB see) (NN lack))))))))) (VP (VB employ) (S (NP (JJ opportun) (NN graduat) (NNS japanes) (ADJP (JJ american) (VBD went) (NN work)) (JJ great) (JJ northern) (NN railway) (NN lay)) (VP (VB maintain) (S (NP (NP (NN track) (NN west) (NN coast)) (PP (IN at) (NP (NP (NN war) (NN onset)) (JJ great) (NML (NML (NML (ADJP (JJ northern) (VBN brought)) (NN japanes)) (NN worker) (NN togeth)) (NN segreg)) (NN gang) (NN outsid)))) (VP (VB restrict) (NP (NML (NML (NN zone) (NN continu)) (NN work)) (NN railroad)) (SBAR (WHNP (TO thu)) (S (VP (VB avoid) (NP (NML (NML (NN incarcer) (NN war)) (NN reloc)) (NN author) (NN camp)) (SBAR (IN while) (S (ADVP (RB away)) (NP (NML (NN father) (NN pick) (NNP fbi)) (VP (VBN sent) (NP (NP (NP (NNP kooskia) (NN intern) (NN camp)) (NN idaho)) (VP (VBN held) (PP (IN throughout) (NP (NML (NN war) (NN draft)) (NN militari) (NML (NN servic) (NN return)) (JJ great) (ADJP (JJ northern) (NN promot)) (NN rank) (NN account))))))) (VP (VB depart) (PP (IN despit) (NP (NN run) (NN workplac) (NN discrimin))))))))))))))))
# (ROOT (S (NP (NML (NNP wilbur) (NNP sato)) (NNP nisei) (ADJP (JJ male) (VBN born)) (NNP april) (NNP pasadena) (NNP california)) (VP (VBD grew) (NP (NML (NNP termin) (NN island)) (NML (NML (NNP california) (NNP dure)) (NN world)) (NN war)) (ADVP (FW ii) (FW remov) (NP (NP (NNP manzanar) (FW concentr) (NN camp)) (NP (NNP california))) (PP (IN after) (S (NP (NML (NML (NN leav) (NN camp)) (NN famili)) (NML (NML (JJ live) (NN time)) (NN hostel) (FW de) (FW moin)) (FW iowa)) (VP (FW return) (NP (NNP california)) (PP (IN after) (NP (NP (NN war)) (JJ becam) (NP (NN attorney) (JJ longtim) (FW commun) (NN activist)))))))))))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-f8d2de43be51> in <cell line: 32>()
#      31
#      32 for sents in dataframe['desc']:
# ---> 33   doc = const(sents)
#      34
#      35   for sentence in doc.sentences:
#
# /usr/local/lib/python3.10/dist-packages/stanza/pipeline/core.py in __call__(self, doc, processors)
#     475
#     476     def __call__(self, doc, processors=None):
# --> 477         return self.process(doc, processors)
#     478
#     479 def main():
#
# /usr/local/lib/python3.10/dist-packages/stanza/pipeline/core.py in process(self, doc, processors)
#     426             if self.processors.get(processor_name):
#     427                 process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 428                 doc = process(doc)
#     429         return doc
#     430
#
# /usr/local/lib/python3.10/dist-packages/stanza/pipeline/constituency_processor.py in process(self, document)
#      58             words = tqdm(words)
#      59
# ---> 60         trees = self._model.parse_tagged_words(words, self._batch_size)
#      61         document.set(CONSTITUENCY, trees, to_sentence=True)
#      62         return document
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/base_model.py in parse_tagged_words(self, words, batch_size)
#     382
#     383         sentence_iterator = iter(words)
# --> 384         treebank = self.parse_sentences_no_grad(sentence_iterator, self.build_batch_from_tagged_words, batch_size, self.predict, keep_state=False, keep_constituents=False)
#     385
#     386         results = [t.predictions[0].tree for t in treebank]
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/base_model.py in parse_sentences_no_grad(self, data_iterator, build_batch_fn, batch_size, transition_choice, keep_state, keep_constituents, keep_scores)
#     347         """
#     348         with torch.no_grad():
# --> 349             return self.parse_sentences(data_iterator, build_batch_fn, batch_size, transition_choice, keep_state, keep_constituents, keep_scores)
#     350
#     351     def analyze_trees(self, trees, batch_size=None, keep_state=True, keep_constituents=True, keep_scores=True):
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/base_model.py in parse_sentences(self, data_iterator, build_batch_fn, batch_size, transition_choice, keep_state, keep_constituents, keep_scores)
#     286         treebank = []
#     287         treebank_indices = []
# --> 288         state_batch = build_batch_fn(batch_size, data_iterator)
#     289         # used to track which indices we are currently parsing
#     290         # since the parses get finished at different times, this will let us unsort after
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/base_model.py in build_batch_from_tagged_words(self, batch_size, data_iterator)
#     263
#     264         if len(state_batch) > 0:
# --> 265             state_batch = self.initial_state_from_words(state_batch)
#     266         return state_batch
#     267
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/base_model.py in initial_state_from_words(self, word_lists)
#     214         preterminal_lists = [[Tree(tag, Tree(word)) for word, tag in words]
#     215                              for words in word_lists]
# --> 216         return self.initial_state_from_preterminals(preterminal_lists, gold_trees=None)
#     217
#     218     def initial_state_from_gold_trees(self, trees):
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/base_model.py in initial_state_from_preterminals(self, preterminal_lists, gold_trees)
#     193         what is passed in should be a list of list of preterminals
#     194         """
# --> 195         word_queues = self.initial_word_queues(preterminal_lists)
#     196         # this is the bottom of the TreeStack and will be the same for each State
#     197         transitions = self.initial_transitions()
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/constituency/lstm_model.py in initial_word_queues(self, tagged_word_lists)
#     744
#     745         if self.forward_charlm is not None:
# --> 746             all_forward_chars = self.forward_charlm.build_char_representation(all_word_labels)
#     747             for word_inputs, forward_chars in zip(all_word_inputs, all_forward_chars):
#     748                 word_inputs.append(forward_chars)
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/common/char_model.py in build_char_representation(self, sentences)
#     220
#     221         with torch.no_grad():
# --> 222             output, _, _ = self.forward(chars, char_lens)
#     223             res = [output[i, offsets] for i, offsets in enumerate(char_offsets)]
#     224             res = unsort(res, orig_idx)
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/common/char_model.py in forward(self, chars, charlens, hidden)
#     151             hidden = (self.charlstm_h_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous(),
#     152                       self.charlstm_c_init.expand(self.args['char_num_layers'], batch_size, self.args['char_hidden_dim']).contiguous())
# --> 153         output, hidden = self.charlstm(embs, charlens, hx=hidden)
#     154         output = self.dropout(pad_packed_sequence(output, batch_first=True)[0])
#     155         decoded = self.decoder(output)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/stanza/models/common/packed_lstm.py in forward(self, input, lengths, hx)
#      20             input = pack_padded_sequence(input, lengths, batch_first=self.batch_first)
#      21
# ---> 22         res = self.lstm(input, hx)
#      23         if self.pad:
#      24             res = (pad_packed_sequence(res[0], batch_first=self.batch_first)[0], res[1])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     880                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     881         else:
# --> 882             result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
#     883                               self.num_layers, self.dropout, self.training, self.bidirectional)
#     884         output = result[0]
#
# KeyboardInterrupt:

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below
'''
I have a love-and-hate relationship with the API. I tried to use the Semantic Scholar API, but their server was not working
and kept sending me 504 and 505. In the end, I decided to scrap the Densho repository instead.

I enjoyed working with the scraper code, but I was lost when diving deeper into the NLP things.
I needed to grasp the concept first before doing the code, especially the Constituency Parsing and Dependency Parsing
I could do the code, but hardly understood what the codes were really about.

The completion time for this assignment was about right from my perspective.

However, would the sentences lose meaning if we clean the sentences (for example, removing stopwords)
and perform the Constituency Parsing or Dependency Parsing?

'''
# Out:
# '\nI have a love-and-hate relationship with the API. I tried to use the Semantic Scholar API, but their server was not working. \nI kept getting 504 and 505. In the end, I decided to scrap the Densho repository instead. \n\nI enjoyed working with the scraper code, but I was lost when diving deeper into the NLP things. \nI needed to grasp the concept first before doing the code. \nI could do the code, but I hardly understood what the codes were\xa0really\xa0about.\n\nThe completion time for this assignment was about right from my\xa0perspective.\n\n'
